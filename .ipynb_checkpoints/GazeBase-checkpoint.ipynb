# %%
import emip_toolkit as emtk
import filter_fixation as ff
# %load_ext autoreload
# %autoreload 2

# %%
pixel_data = ff.process_GazeBase('S_1001_S1_TEX.csv')
fixations, saccades = ff.filter_fixations(pixel_data)

# %%
test_trial = emtk.Trial(trial_id=0,
                       participant_id="001",
                       image="TEX_R1S1_bg.png",
                       fixations=fixations,
                       saccades=saccades,
                       blinks={},
                       samples={},
                       eye_tracker="EyeLink1000_")

# %%
test_trial.draw_trial('', draw_saccade=False, draw_aoi=True)

# %%
aoi = emtk.find_aoi(image='TEX_R1S1_bg.png', image_path='')

# %%
emtk.draw_aoi(aoi, image='TEX_R1S1_bg.png', image_path='')
# Out:
# <PIL.Image.Image image mode=1 size=1680x1050 at 0x11844B7C0>

# %%
aoi.head()
# Out:
#        kind           name      x   y width height local_id            image
# 0  sub-line  line 1 part 1  739.5   5    63     26      NaN  TEX_R1S1_bg.png
# 1  sub-line  line 1 part 2  805.5   5   136     26      NaN  TEX_R1S1_bg.png
# 2  sub-line  line 2 part 1  553.5  71    70     32      NaN  TEX_R1S1_bg.png
# 3  sub-line  line 2 part 2  624.5  71    42     32      NaN  TEX_R1S1_bg.png
# 4  sub-line  line 2 part 3  669.5  71    66     32      NaN  TEX_R1S1_bg.png

# %%
aoi_token = emtk.add_tokens_to_AOIs(file_path='', aois_raw=aoi)
aoi_token
# Out:
#          kind            name       x    y width height local_id  \
# 0    sub-line   line 1 part 1   739.5    5    63     26      NaN
# 1    sub-line   line 1 part 2   805.5    5   136     26      NaN
# 2    sub-line   line 2 part 1   553.5   71    70     32      NaN
# 3    sub-line   line 2 part 2   624.5   71    42     32      NaN
# 4    sub-line   line 2 part 3   669.5   71    66     32      NaN
# ..        ...             ...     ...  ...   ...    ...      ...
# 187  sub-line  line 25 part 5   810.5  995    50     32      NaN
# 188  sub-line  line 25 part 6   863.5  995    90     32      NaN
# 189  sub-line  line 25 part 7   954.5  995    41     32      NaN
# 190  sub-line  line 25 part 8   996.5  995    42     32      NaN
# 191  sub-line  line 25 part 9  1040.5  995    56     32      NaN
#
#                image    token
# 0    TEX_R1S1_bg.png     THIE
# 1    TEX_R1S1_bg.png  LANDING
# 2    TEX_R1S1_bg.png    "Just
# 3    TEX_R1S1_bg.png      the
# ...

# %%
emtk.hit_test(test_trial, aoi_token)
# Out:
# all fixations: 311
#     trial participant        code_file    code_language  timestamp duration  \
# 0       1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png      142.0       27
# 1       1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png      263.0      120
# 2       1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png      263.0      120
# 3       1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png      519.0      255
# 4       1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png      519.0      255
# ..    ...         ...              ...              ...        ...      ...
# 373     1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png    59789.0       23
# 374     1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png    60102.0      146
# 375     1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png    60102.0      146
# 376     1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png    60122.0       14
# 377     1         001  TEX_R1S1_bg.png  TEX_R1S1_bg.png    60122.0       14
#
# ...
