# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Eight_Metrics.csv')

df = df.dropna(subset=['token'])

df['nSFD'] = df.loc[:,'SFD'] / df['length']
df['nFFD'] = df.loc[:,'FFD'] / df['length']
df['nGD'] = df.loc[:,'GD'] / df['length']
df['nTT'] = df.loc[:,'TT'] / df['length']

# %%
df_
# Out:
#         file  line  part    token  subject    SFD    FFD     GD     TT   PrF  \
# 0         11    12     3  brought        1    NaN  120.0  120.0  836.0  0.00
# 1         11    13     3   broker        1    NaN  120.0  120.0  700.0  0.00
# 2         11    12     4       to        1    NaN  161.0  161.0  353.0  0.00
# 3         11    13     4       to        1  161.0  161.0  161.0  161.0  0.00
# 4         11    12     5  arrange        1    NaN   74.0   74.0  695.0  0.00
# ...      ...   ...   ...      ...      ...    ...    ...    ...    ...   ...
# 230685    92    24     8       of      314    NaN  267.0  267.0  732.0  0.07
# 230686    92    25     5       of      314    NaN  267.0  267.0  829.0  0.07
# 230687    92    25     1       in      314    NaN  136.0  136.0  363.0  0.07
# 230688    92     3     3       if      314    NaN  181.0  181.0  363.0  0.07
# 230689    92     4     5     twas      314  175.0  175.0  175.0  175.0  0.07
#
# ...

# %%
df_ = df.copy()
df_.nSFD = df_.nSFD.fillna(0)

# %%
df_['subject']
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#          ...
# 230685    314
# 230686    314
# 230687    314
# 230688    314
# 230689    314
# Name: subject, Length: 230552, dtype: int64

# %%
columns = 'nFFD nGD nTT PrF Pr1 Pr2 PrS freq length subject'.split() # nSFD was dropped
df

scaler = MinMaxScaler()

X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)

train, test = train_test_split(df[columns], train_size=0.7)

# %%
df
# Out:
#         file  line  part    token  subject    SFD    FFD     GD     TT   PrF  \
# 0         11    12     3  brought        1    NaN  120.0  120.0  836.0  0.00
# 1         11    13     3   broker        1    NaN  120.0  120.0  700.0  0.00
# 2         11    12     4       to        1    NaN  161.0  161.0  353.0  0.00
# 3         11    13     4       to        1  161.0  161.0  161.0  161.0  0.00
# 4         11    12     5  arrange        1    NaN   74.0   74.0  695.0  0.00
# ...      ...   ...   ...      ...      ...    ...    ...    ...    ...   ...
# 230685    92    24     8       of      314    NaN  267.0  267.0  732.0  0.07
# 230686    92    25     5       of      314    NaN  267.0  267.0  829.0  0.07
# 230687    92    25     1       in      314    NaN  136.0  136.0  363.0  0.07
# 230688    92     3     3       if      314    NaN  181.0  181.0  363.0  0.07
# 230689    92     4     5     twas      314  175.0  175.0  175.0  175.0  0.07
#
# ...

# %%
train_target = (train["class"] == 0)
train_data = train.drop(["class"], axis=1)

test_target = (test["class"] == 0)
test_data = test.drop(["class"], axis=1)

print('train:', train_target.shape)
print('test:', test_target.shape)

# %%
RandomForestClassifier?

# %%
clf = RandomForestClassifier()

clf.fit(X_train,y_train)

# y_pred = clf.predict(X_test)
# Out:
# RandomForestClassifier()

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.015592808657370259

# %%
metrics.accuracy_score(y_train, clf.predict(X_train))
# Out:
# 0.8832309519033187

# %% [markdown]
# 1. precision and recall
# 2. confusion matrix
# 3. cross validation

# %%
from sklearn.model_selection import cross_val_score
import statistics

statistics.mean(cross_val_score(clf, test_data, y_test, cv=10, scoring="accuracy"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3h/wbvtqh2d001gvnsysbmn8c3w0000gs/T/ipykernel_42438/1713424263.py in <module>
#       2 import statistics
#       3
# ----> 4 statistics.mean(cross_val_score(clf, X_test, y_test, cv=10, scoring="accuracy"))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
# ...

# %%
from sklearn.model_selection import cross_val_predict

test_predict = cross_val_predict(clf, X_test, y, cv=10)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision_score(test_target, test_predict)

recall_score(test_target, test_predict)

f1_score(test_target, test_predict)

from sklearn.metrics import confusion_matrix

confusion_matrix(test_target, test_predict)
