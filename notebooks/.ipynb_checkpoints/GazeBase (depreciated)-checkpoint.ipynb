# %%
import emip_toolkit as emtk
import filter_fixation as ff
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d0b5b62370fd> in <module>
# ----> 1 import emip_toolkit as emtk
#       2 import filter_fixation as ff
#       3 get_ipython().run_line_magic('load_ext', 'autoreload')
#       4 get_ipython().run_line_magic('autoreload', '2')
#
# ModuleNotFoundError: No module named 'emip_toolkit'

# %%
pixel_data = ff.process_GazeBase('datasets/GazeBase_TEX/Data/S_1001_S2_TEX.csv')
fixations, saccades = ff.filter_fixations(pixel_data)

test_trial = emtk.Trial(trial_id=2,
                       participant_id="001",
                       image="TEX_R1S2_bg.png",
                       fixations=fixations,
                       saccades=saccades,
                       blinks={},
                       samples={},
                       eye_tracker="EyeLink1000_")

image_path = 'datasets/GazeBase_TEX/StimuliExamples/TEXScreenshots/'
test_trial.draw_trial(image_path=image_path, draw_saccade=True, draw_aoi=True, draw_number=False)

# %%
pixel_data = ff.process_GazeBase('datasets/GazeBase_TEX/Data/S_1002_S2_TEX.csv')
fixations, saccades = ff.filter_fixations(pixel_data)

test_trial = emtk.Trial(trial_id=2,
                       participant_id="002",
                       image="TEX_R1S2_bg.png",
                       fixations=fixations,
                       saccades=saccades,
                       blinks={},
                       samples={},
                       eye_tracker="EyeLink1000_")

image_path = 'datasets/GazeBase_TEX/StimuliExamples/TEXScreenshots/'
test_trial.draw_trial(image_path=image_path, draw_saccade=True, draw_aoi=True, draw_number=False)

# %%
aoi = emtk.find_aoi(image='TEX_R1S2_bg.png', image_path=image_path)

emtk.draw_aoi(aoi, image='TEX_R1S2_bg.png', image_path=image_path)
# Out:
# <PIL.Image.Image image mode=1 size=1680x1050 at 0x1194A1220>

# %%
aoi.head()
# Out:
#        kind           name      x   y width height local_id            image
# 0  sub-line  line 1 part 1  739.5   5    63     26      NaN  TEX_R1S1_bg.png
# 1  sub-line  line 1 part 2  805.5   5   136     26      NaN  TEX_R1S1_bg.png
# 2  sub-line  line 2 part 1  553.5  71    70     32      NaN  TEX_R1S1_bg.png
# 3  sub-line  line 2 part 2  624.5  71    42     32      NaN  TEX_R1S1_bg.png
# 4  sub-line  line 2 part 3  669.5  71    66     32      NaN  TEX_R1S1_bg.png

# %%
file_path = 'datasets/GazeBase_TEX/StimuliExamples/TEXTexts/'
aoi_token = emtk.add_tokens_to_AOIs(file_path=file_path, aois_raw=aoi)
aoi_token
# Out:
#          kind            name       x    y width height local_id  \
# 0    sub-line   line 1 part 1   739.5    5    63     26      NaN
# 1    sub-line   line 1 part 2   805.5    5   136     26      NaN
# 2    sub-line   line 2 part 1   553.5   71    70     32      NaN
# 3    sub-line   line 2 part 2   624.5   71    42     32      NaN
# 4    sub-line   line 2 part 3   669.5   71    66     32      NaN
# ..        ...             ...     ...  ...   ...    ...      ...
# 187  sub-line  line 25 part 5   810.5  995    50     32      NaN
# 188  sub-line  line 25 part 6   863.5  995    90     32      NaN
# 189  sub-line  line 25 part 7   954.5  995    41     32      NaN
# 190  sub-line  line 25 part 8   996.5  995    42     32      NaN
# 191  sub-line  line 25 part 9  1040.5  995    56     32      NaN
#
#                image    token
# 0    TEX_R1S1_bg.png      THE
# 1    TEX_R1S1_bg.png  LANDING
# 2    TEX_R1S1_bg.png    "Just
# 3    TEX_R1S1_bg.png      the
# 4    TEX_R1S1_bg.png    place
# ..               ...      ...
# 187  TEX_R1S1_bg.png      had
# 188  TEX_R1S1_bg.png   bought
# 189  TEX_R1S1_bg.png      for
# 190  TEX_R1S1_bg.png      the
# 191  TEX_R1S1_bg.png    trip.
#
# [192 rows x 9 columns]

# %%
df = emtk.hit_test(test_trial, aoi_token)
# Out:
# all fixations: 311

# %%
df.to_csv('Hit Test Result.csv')

# %% [markdown]
# ## Mega Result

# %%
from tqdm import tqdm

import os
import pandas as pd

file_lst = []

tex_file_path = 'datasets/GazeBase_TEX/TEX/'
for r, d, f in os.walk(tex_file_path):
    for file_name in f:
        if file_name.endswith('TEX.csv'):
            file_lst.append(tex_file_path + file_name)

import emip_toolkit as emtk
import filter_fixation as ff
# %load_ext autoreload
# %autoreload 2

# %%
image_path = 'datasets/GazeBase_TEX/StimuliExamples/TEXScreenshots/'
file_path = 'datasets/GazeBase_TEX/StimuliExamples/TEXTexts/'

headers = ["round",
           "session",
           "participant",
           "line_part",
           "stimuli_image",
           "stimuli_text",
           "timestamp",
           "duration",
           "x_cord",
           "y_cord",
           "aoi_x",
           "aoi_y",
           "aoi_width",
           "aoi_height",
           "token",
           "length"]

mega_result = pd.DataFrame(columns=headers)

gone = []

for file in tqdm(file_lst):

    pixel_data = ff.process_GazeBase(file)
    fixations, saccades = ff.filter_fixations(pixel_data, sample_duration=1)
    
    file_name = file.split('/')[-1]
    
    round_id = file_name[2]
    participant_id = file_name[3:6]
    session_id = file_name[8]
    image = f'TEX_R{round_id}S{session_id}_bg.png'
    
    for fix in fixations.values():
        fix.trial_id = round_id + session_id
        fix.participant_id = participant_id

    for sac in saccades.values():
        sac.trial_id = round_id + session_id
        sac.participant_id = participant_id

    trial = emtk.Trial(trial_id=round_id+session_id,
                       participant_id=participant_id,
                       image=image,
                       fixations=fixations,
                       saccades=saccades,
                       blinks={},
                       samples={},
                       eye_tracker="EyeLink1000_")
    
    aoi = emtk.find_aoi(image=trial.image, image_path=image_path)
    aoi_token = emtk.add_tokens_to_AOIs(file_path=file_path, aois_raw=aoi)
    df = emtk.hit_test_GazeBase(trial, aoi_token)
    
    mega_result = pd.concat([mega_result, df])
# Out:
#   1%|▍                                      | 17/1762 [03:31<6:01:22, 12.43s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3h/wbvtqh2d001gvnsysbmn8c3w0000gs/T/ipykernel_65107/448256779.py in <module>
#      52                        eye_tracker="EyeLink1000_")
#      53
# ---> 54     aoi = emtk.find_aoi(image=trial.image, image_path=image_path)
#      55     aoi_token = emtk.add_tokens_to_AOIs(file_path=file_path, aois_raw=aoi)
#      56     df = emtk.hit_test_GazeBase(trial, aoi_token)
#
# ~/Documents/GitHub/EMIP-Toolkit/emip_toolkit.py in find_aoi(image, image_path, img, level, margin_height, margin_width)
#    1201
#    1202             box = (left, upper_bound, right, lower_bound)
# -> 1203             minimum, maximum = img.crop(box).getextrema()
#    1204
#    1205             if left > 1:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py in crop(self, box)
#    1170
#    1171         self.load()
# -> 1172         return self._new(self._crop(self.im, box))
#    1173
#    1174     def _crop(self, im, box):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py in _new(self, im)
#     570
#     571                 new.palette = ImagePalette.ImagePalette()
# --> 572         new.info = self.info.copy()
#     573         return new
#     574
#
# KeyboardInterrupt:

# %%
# %store -r mega1
# %store -r mega2
# %store -r mega3
# %store -r mega4

# %%
import pandas as pd

# %%
mega_result = pd.concat([mega1, mega2, mega3, mega4])

# %%
mega_result.to_csv('Hit_Test_Result.csv')

# %%
mega_result.reset_index(inplace=True)

# %%
datatype = {'index': str,
            'round': str, 
            'session': str,
            'line_part': str,
            'participant': str,
            'stimuli_image': str,
            'stimuli_text': str,
            'duration': 'int64',
            'x_cord': 'float64',
            'y_cord': 'float64',
            'aoi_x': 'float64',
            'aoi_y': 'float64', 
            'aoi_width': 'float64', 
            'aoi_height': 'float64',
            'token': str,
            'length': 'int64'}

mega_result = mega_result.astype(datatype)

# %%
mega_result.dtypes
# Out:
# index             object
# round             object
# session           object
# participant       object
# line_part         object
# stimuli_image     object
# stimuli_text      object
# timestamp        float64
# duration           int64
# x_cord           float64
# y_cord           float64
# aoi_x            float64
# aoi_y            float64
# aoi_width        float64
# aoi_height       float64
# token             object
# length             int64
# dtype: object

# %%
mega_result['index'] = mega_result['round'] + mega_result['session'] + mega_result['participant'] + '_' + mega_result['index']

# %%
mega_result.to_csv('raw_result.csv')

# %%
df = pd.read_csv('raw_result.csv', dtype=datatype)

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# index             object
# round             object
# session           object
# participant       object
# line_part         object
# stimuli_image     object
# stimuli_text      object
# timestamp        float64
# duration           int64
# x_cord           float64
# y_cord           float64
# aoi_x            float64
# aoi_y            float64
# aoi_width        float64
# aoi_height       float64
# token             object
# length             int64
# dtype: object

# %%
df
# Out:
#         Unnamed: 0      index round session participant       line_part  \
# 0                0    11001_0     1       1         001  line 12 part 3
# 1                1    11001_1     1       1         001  line 13 part 3
# 2                2    11001_2     1       1         001  line 12 part 3
# 3                3    11001_3     1       1         001  line 13 part 3
# 4                4    11001_4     1       1         001  line 12 part 4
# ...            ...        ...   ...     ...         ...             ...
# 537661      537661  92314_304     9       2         314   line 7 part 5
# 537662      537662  92314_305     9       2         314   line 6 part 6
# 537663      537663  92314_306     9       2         314   line 7 part 5
# 537664      537664  92314_307     9       2         314   line 6 part 7
# 537665      537665  92314_308     9       2         314   line 7 part 5
#
#           stimuli_image       stimuli_text  timestamp  duration       x_cord  \
# 0       TEX_R1S1_bg.png  TEX_R1S1_text.txt      263.0       120   722.360000
# 1       TEX_R1S1_bg.png  TEX_R1S1_text.txt      263.0       120   722.360000
# 2       TEX_R1S1_bg.png  TEX_R1S1_text.txt      519.0       255   736.400394
# 3       TEX_R1S1_bg.png  TEX_R1S1_text.txt      519.0       255   736.400394
# 4       TEX_R1S1_bg.png  TEX_R1S1_text.txt      698.0       161   809.180746
# ...                 ...                ...        ...       ...          ...
# 537661  TEX_R9S2_bg.png  TEX_R9S2_text.txt    59424.0        70  1043.085715
# 537662  TEX_R9S2_bg.png  TEX_R9S2_text.txt    59573.0       148  1046.345271
# 537663  TEX_R9S2_bg.png  TEX_R9S2_text.txt    59573.0       148  1046.345271
# 537664  TEX_R9S2_bg.png  TEX_R9S2_text.txt    59946.0       364  1081.592856
# 537665  TEX_R9S2_bg.png  TEX_R9S2_text.txt    59946.0       364  1081.592856
#
#             y_cord   aoi_x  aoi_y  aoi_width  aoi_height       token  length
# 0       488.112500   700.5  467.0      102.0        32.0     brought       7
# 1       488.112500   708.5  500.0       96.0        32.0     Broker,       7
# 2       491.933725   700.5  467.0      102.0        32.0     brought       7
# 3       491.933725   708.5  500.0       96.0        32.0     Broker,       7
# 4       494.226708   803.5  467.0       28.0        32.0          to       2
# ...            ...     ...    ...        ...         ...         ...     ...
# 537661  265.241425   928.5  269.0      159.0        32.0       every       5
# 537662  264.358783   946.5  236.0      130.0        32.0  frequently      10
# 537663  264.358783   928.5  269.0      159.0        32.0       every       5
# 537664  260.325826  1077.5  236.0       65.0        32.0       finds       5
# 537665  260.325826   928.5  269.0      159.0        32.0       every       5
#
# [537666 rows x 18 columns]

# %%
import string
df['token'] = df['token'].str.lower().str.strip(string.punctuation)
df['length'] = df['token'].str.len()

# %%
df.to_csv('processed_result.csv')

# %%
frequency = pd.read_csv('tokens_freq.csv')

# %%
frequency.set_index('Word', inplace=True)

# %%
freq = frequency.groupby('Word').max()

# %%
freq_dict = freq.to_dict()

# %%
freq_dict
# Out:
# {' Lemma Head': {'a': ' a',
#   'able': ' able',
#   'aboard': ' aboard',
#   'about': ' about',
#   'absolute': ' absolute',
#   'absurd': ' absurd',
#   'add': ' add',
#   'added': ' add',
#   'additional': ' additional',
#   'advised': ' advise',
#   'affectionate': ' affectionate',
#   'after': ' after',
#   'again': ' again',
#   'against': ' against',
#   'ages': ' age',
#   'agree': ' agree',
#   'ahead': ' ahead',
#   'all': ' all',
#   'almost': ' almost',
#   'alone': ' alone',
#   'along': ' along',
#   'already': ' already',
#   'also': ' also',
#   'although': ' although',
#   'always': ' always',
#   'am': ' be',
#   'ambition': ' ambition',
#   'among': ' among',
#   'amount': ' amount',
#   'amply': ' amply',
#   'an': ' an',
#   'and': ' and',
#   'angrily': ' angrily',
#   'another': ' another',
#   'answer': ' answer',
#   'antediluvian': ' antediluvian',
#   'any': ' any',
#   'appeal': ' appeal',
#   'appeared': ' appear',
#   'approach': ' approach',
#   'are': ' be',
#   'arrange': ' arrange',
#   'arrangement': ' arrangement',
#   'art': ' be',
#   'as': ' as',
#   'asleep': ' asleep',
#   'at': ' at',
#   'atone': ' atone',
#   'attempting': ' attempt',
#   'attending': ' attend',
#   'away': ' away',
#   'awkward': ' awkward',
#   'bade': ' bid',
#   'bags': ' bags',
#   'bake': ' bake',
#   'baker': ' baker',
#   'bands': ' band',
#   'banker': ' banker',
#   'barrister': ' barrister',
#   'batch': ' batch',
#   'bathing-machines': ' bathing-machine',
#   'be': ' be',
#   'beach': ' beach',
#   'bear': ' bear',
#   'beauty': ' beauty',
#   'beaver': ' beaver',
#   'beavers': ' beaver',
#   'became': ' become',
#   'becomes': ' become',
#   'been': ' be',
#   'before': ' before',
#   'began': ' begin',
#   'beginning': ' beginning',
#   'beheld': ' behold',
#   'behind': ' behind',
#   'being': ' being',
#   'believes': ' believe',
#   'bell': ' bell',
#   'best': ' well',
#   'betrayed': ' betray',
#   'beware': ' beware',
#   'bewilder': ' bewilder',
#   'billiard-marker': ' billiard-marker',
#   'billowy': ' billowy',
#   'bird': ' bird',
#   'bite': ' bite',
#   'blank': ' blank',
#   'blew': ' blow',
#   'blissful': ' blissful',
#   'board': ' board',
#   'boil': ' boil',
#   'bold': ' bold',
#   'bonnets': ' bonnet',
#   'books': ' books',
#   'boots': ' boots',
#   'bought': ' buy',
#   'bow': ' bow',
#   'bowl': ' bowl',
#   'bowsprit': ' bowsprit',
#   'boxes': ' box',
#   'brains': ' brains',
#   'brave': ' brave',
#   'breakfasts': ' breakfast',
#   'brimming': ' brim',
#   'bring': ' bring',
#   'broke': ' broke',
#   'broker': ' broker',
#   'brought': ' bring',
#   'brow': ' brow',
#   'but': ' but',
#   'butcher': ' butcher',
#   'by': ' by',
#   'call': ' call',
#   'called': ' call',
#   'came': ' come',
#   'can': ' can',
#   'cannot': ' cannot',
#   'capes': ' cape',
#   'captain': ' captain',
#   'capture': ' capture',
#   'care': ' care',
#   'carefully': ' carefully',
#   'carriage': ' carriage',
#   'carries': ' carry',
#   'cases': ' case',
#   'cash': ' cash',
#   'caught': ' catch',
#   'caused': ' cause',
#   'cemented': ' cement',
#   'chalking': ' chalk',
#   'chance': ' chance',
#   'changed': ' change',
#   'charge': ' charge',
#   'charm': ' charm',
#   'charmed': ' charm',
#   'charming': ' charming',
#   'chasms': ' chasm',
#   'check': ' check',
#   'childhood': ' childhood',
#   'chosen': ' choose',
#   'cite': ' cite',
#   'clear': ' clear',
#   'clearly': ' clearly',
#   'climes': ' clime',
#   'clothes': ' clothes',
#   'coat': ' coat',
#   'coats': ' coat',
#   'colder': ' cold',
#   'combed': ' comb',
#   'come': ' come',
#   'common': ' common',
#   'commonplace': ' commonplace',
#   'complete': ' complete',
#   'concern': ' concern',
#   'condense': ' condense',
#   'confessed': ' confessed',
#   'considered': ' considered',
#   'constantly': ' constantly',
#   'contrived': ' contrived',
#   'conundrums': ' conundrum',
#   'convenient': ' convenient',
#   'conventional': ' conventional',
#   'conveyed': ' convey',
#   'cooked': ' cook',
#   'costume': ' costume',
#   'could': ' can',
#   'count': ' count',
#   'counted': ' count',
#   'countrymen': ' countryman',
#   'courage': ' courage',
#   'course': ' course',
#   'court': ' court',
#   'crags': ' crag',
#   'creature': ' creature',
#   'creatures': ' creature',
#   'creepy': ' creepy',
#   'cress': ' cress',
#   'crew': ' crow',
#   'cried': ' cry',
#   'crimes': ' crime',
#   'crisp': ' crisp',
#   'crossed': ' cross',
#   'crossing': ' crossing',
#   'cry': ' cry',
#   'curds': ' curd',
#   'damage': ' damage',
#   'danger': ' danger',
#   'dark': ' dark',
#   'darker': ' dark',
#   'day': ' day',
#   'days': ' days',
#   'dear': ' dear',
#   'death': ' death',
#   'debate': ' debate',
#   'deck': ' deck',
#   'declared': ' declared',
#   'decline': ' decline',
#   'deeply': ' deeply',
#   'defending': ' defend',
#   'delight': ' delight',
#   'delirious': ' delirious',
#   'delivered': ' deliver',
#   'depend': ' depend',
#   'deplored': ' deplore',
#   'describe': ' describe',
#   'deserted': ' desert',
#   'deserting': ' desert',
#   'desolate': ' desolate',
#   'despair': ' despair',
#   'desperate': ' desperate',
#   'did': ' do',
#   'difficult': ' difficult',
#   'diminished': ' diminish',
#   'dine': ' dine',
#   'dines': ' dine',
#   'disgust': ' disgust',
#   'dismal': ' dismal',
#   'displayed': ' display',
#   'disputes': ' dispute',
#   'distinguishing': ' distinguish',
#   'distressed': ' distress',
#   'divide': ' divide',
#   'do': ' do',
#   'does': ' doe',
#   "don't": " don't",
#   'done': ' done',
#   'door': ' door',
#   'doubt': ' doubt',
#   'down': ' down',
#   'drank': ' drink',
#   'dread': ' dread',
#   'dream': ' dream',
#   'dreamed': ' dream',
#   'dreams': ' dream',
#   'dreamy': ' dreamy',
#   'dressed': ' dress',
#   'drove': ' drove',
#   'due': ' due',
#   'dunce': ' dunce',
#   'dust': ' dust',
#   'duty': ' duty',
#   'dwelt': ' dwell',
#   'each': ' each',
#   'earlier': ' early',
#   'ears': ' ear',
#   'earth': ' earth',
#   'ease': ' ease',
#   'east': ' east',
#   'effort': ' effort',
#   'eggs': ' egg',
#   'eight': ' eight',
#   'either': ' either',
#   'eloquent': ' eloquent',
#   'embarked': ' embark',
#   'emotion': ' emotion',
#   'employed': ' employ',
#   'encourage': ' encourage',
#   'end': ' end',
#   'endorsed': ' endorse',
#   'endure': ' endure',
#   'enemies': ' enemy',
#   'engage': ' engage',
#   'engaged': ' engaged',
#   'engrossed': ' engross',
#   'enormous': ' enormous',
#   'enough': ' enough',
#   'entered': ' enter',
#   'entirely': ' entirely',
#   'entwined': ' entwine',
#   'enveloped': ' envelop',
#   'error': ' error',
#   'especial': ' especial',
#   'especially': ' especially',
#   'even': ' even',
#   'evening': ' evening',
#   'ever': ' ever',
#   'every': ' every',
#   'exactly': ' exactly',
#   'excellent': ' excellent',
#   'excessively': ' excessively',
#   'excitedly': ' excitedly',
#   'exclaimed': ' exclaim',
#   'expense': ' expense',
#   'explain': ' explain',
#   'explained': ' explain',
#   'explaining': ' explain',
#   'exquisite': ' exquisite',
#   'extra': ' extra',
#   'eye': ' eye',
#   'eyes': ' eyes',
#   'face': ' face',
#   'fact': ' fact',
#   'failing': ' failing',
#   'fainted': ' faint',
#   'fairly': ' fairly',
#   'false': ' false',
#   'famed': ' famed',
#   'fancy': ' fancy',
#   'far': ' far',
#   'father': ' father',
#   'feared': ' fear',
#   'feathers': ' feather',
#   'feel': ' feel',
#   'fell': ' fell',
#   'fellow': ' fellow',
#   'felt': ' felt',
#   'ferociously': ' ferociously',
#   'fetch': ' fetch',
#   'fifth': ' fifth',
#   'fight': ' fight',
#   'find': ' find',
#   'finds': ' find',
#   'finger': ' finger',
#   'fingers': ' finger',
#   'fire': ' fire',
#   'first': ' first',
#   'fit': ' fit',
#   'five': ' five',
#   'fixed': ' fixed',
#   'flavour': ' flavour',
#   'flaw': ' flaw',
#   'following': ' following',
#   'fond': ' fond',
#   'fondness': ' fondness',
#   'for': ' for',
#   'forbear': ' forbear',
#   'forcible': ' forcible',
#   'forgetting': ' forget',
#   'forgot': ' forget',
#   'forgotten': ' forget',
#   'forks': ' fork',
#   'form': ' form',
#   'forty': ' forty',
#   'found': ' found',
#   'four': ' four',
#   'fourth': ' fourth',
#   'frequently': ' frequently',
#   'friend': ' friend',
#   'friends': ' friends',
#   'friendship': ' friendship',
#   'frightened': ' frightened',
#   'fritter': ' fritter',
#   'from': ' from',
#   'fry': ' fry',
#   'further': ' further',
#   'galumphing': ' galumph',
#   'gave': ' give',
#   'gaze': ' gaze',
#   'genial': ' genial',
#   'genuine': ' genuine',
#   'getting': ' get',
#   'give': ' give',
#   'giving': ' give',
#   'gladly': ' gladly',
#   'glass': ' glass',
#   'glimpse': ' glimpse',
#   'glorious': ' glorious',
#   'gloves': ' glove',
#   'glue': ' glue',
#   'go': ' go',
#   'going': ' going',
#   'good': ' good',
#   'goods': ' goods',
#   'got': ' get',
#   'gown': ' gown',
#   'grace': ' grace',
#   'grand': ' grand',
#   'grave': ' grave',
#   'gravely': ' gravely',
#   'greens': ' greens',
#   'grew': ' grow',
#   'grieve': ' grieve',
#   'grindstone': ' grindstone',
#   'groan': ' groan',
#   'grog': ' grog',
#   'grown': ' grown',
#   'guess': ' guess',
#   'habit': ' habit',
#   'had': ' have',
#   'hair': ' hair',
#   'hand': ' hand',
#   'handy': ' handy',
#   'happen': ' happen',
#   'happened': ' happen',
#   'happens': ' happen',
#   'hardly': ' hardly',
#   'has': ' have',
#   'haste': ' haste',
#   'hasty': ' hasty',
#   'have': ' have',
#   'he': ' he',
#   "he's": " he's",
#   'head': ' head',
#   'health': ' health',
#   'hear': ' hear',
#   'heard': ' hear',
#   'heart': ' heart',
#   'heeded': ' heed',
#   'helmsman': ' helmsman',
#   'help': ' help',
#   'her': ' her',
#   'hi': ' hi',
#   'high': ' high',
#   'him': ' him',
#   'himself': ' himself',
#   'hire': ' hire',
#   'his': ' his',
#   'history': ' history',
#   'hitherto': ' hitherto',
#   'ho': ' ho',
#   'hollow': ' hollow',
#   'home': ' home',
#   'honest': ' honest',
#   'hope': ' hope',
#   'hoped': ' hope',
#   'how': ' how',
#   'howl': ' howl',
#   'hundred': ' hundred',
#   'hunt': ' hunt',
#   'hunting': ' hunting',
#   'hyenas': ' hyena',
#   'i': ' i',
#   'ice': ' ice',
#   'if': ' if',
#   'immense': ' immense',
#   'impudent': ' impudent',
#   'in': ' in',
#   'included': ' included',
#   'incredible': ' incredible',
#   'indignantly': ' indignantly',
#   'informed': ' informed',
#   'infringement': ' infringement',
#   'ingenious': ' ingenious',
#   'ink': ' ink',
#   'innocent': ' innocent',
#   'instruction': ' instruction',
#   'insure': ' insure',
#   'intellect': ' intellect',
#   'interest': ' interest',
#   'intimate': ' intimate',
#   'introduce': ' introduce',
#   'introduction': ' introduction',
#   'is': ' be',
#   'islands': ' island',
#   'it': ' it',
#   "it's": " it's",
#   'its': ' its',
#   'ivory': ' ivory',
#   'jam': ' jam',
#   'jewels': ' jewel',
#   'joke': ' joke',
#   'jokes': ' joke',
#   'judge': ' judge',
#   'just': ' just',
#   'keep': ' keep',
#   'keeping': ' keeping',
#   'keeps': ' keeps',
#   'kegs': ' keg',
#   'kept': ' keep',
#   'kid': ' kid',
#   'kill': ' kill',
#   'knew': ' know',
#   'know': ' know',
#   'knows': ' know',
#   'lace': ' lace',
#   'landed': ' landed',
#   'landing': ' landing',
#   'larboard': ' larboard',
#   'large': ' large',
#   'last': ' last',
#   'late': ' late',
#   'laws': ' law',
#   'learned': ' learned',
#   'least': ' little',
#   'left': ' left',
#   'leisure': ' leisure',
#   'lend': ' lend',
#   'length': ' length',
#   'lesson': ' lesson',
#   'let': ' let',
#   'liberal': ' liberal',
#   'life': ' life',
#   'light': ' light',
#   'like': ' like',
#   'lines': ' lines',
#   'listen': ' listen',
#   'lives': ' live',
#   'locusts': ' locust',
#   'long': ' long',
#   'longer': ' long',
#   'look': ' look',
#   'looked': ' look',
#   'looking': ' look',
#   'looks': ' looks',
#   'loose': ' loose',
#   'lose': ' lose',
#   'loss': ' loss',
#   'lost': ' lose',
#   'loud': ' loud',
#   'lovingly': ' lovingly',
#   'low': ' low',
#   'made': ' make',
#   'mahogany': ' mahogany',
#   'maker': ' maker',
#   'making': ' making',
#   'man': ' man',
#   'manner': ' manner',
#   'many': ' many',
#   'map': ' map',
#   'maps': ' map',
#   'marched': ' march',
#   'mark': ' mark',
#   'marks': ' mark',
#   'materials': ' material',
#   'mattered': ' matter',
#   'maxim': ' maxim',
#   'may': ' may',
#   'me': ' me',
#   'meagre': ' meagre',
#   'meet': ' meet',
#   'men': ' man',
#   'mention': ' mention',
#   'merely': ' merely',
#   'meridian': ' meridian',
#   'met': ' meet',
#   'method': ' method',
#   'might': ' might',
#   'mildest': ' mild',
#   'mind': ' mind',
#   'mine': ' mine',
#   'minute': ' minute',
#   'mixed': ' mixed',
#   'moderate': ' moderate',
#   'moment': ' moment',
#   'month': ' month',
#   'months': ' month',
#   'more': ' much',
#   'mother': ' mother',
#   'much': ' much',
#   'musical': ' musical',
#   'must': ' must',
#   'mustard': ' mustard',
#   'mutton': ' mutton',
#   'my': ' my',
#   'mystery': ' mystery',
#   'name': ' name',
#   'names': ' name',
#   'narrow': ' narrow',
#   'narrower': ' narrow',
#   'natural': ' natural',
#   'navigation': ' navigation',
#   'near': ' near',
#   'need': ' need',
#   'needs': ' needs',
#   'neither': ' neither',
#   'nephew': ' nephew',
#   'nervous': ' nervous',
#   'nervousness': ' nervousness',
#   'never': ' never',
#   'next': ' next',
#   'night': ' night',
#   'nine': ' nine',
#   'ninety': ' ninety',
#   'no': ' no',
#   'noble': ' noble',
#   'nodding': ' nod',
#   'none': ' none',
#   'north': ' north',
#   'not': ' not',
#   'note': ' note',
#   'notes': ' note',
#   'nothing': ' nothing',
#   'notion': ' notion',
#   'novel': ' novel',
#   'now': ' now',
#   'number': ' number',
#   'object': ' object',
#   'occurred': ' occur',
#   'ocean': ' ocean',
#   'of': ' of',
#   'off': ' off',
#   'offered': ' offer',
#   'office': ' office',
#   'often': ' often',
#   'oh': ' oh',
#   'omitted': ' omit',
#   'on': ' on',
#   'once': ' once',
#   'one': ' one',
#   'only': ' only',
#   'open': ' open',
#   'opposite': ' opposite',
#   'oppresses': ' oppress',
#   'or': ' or',
#   'order': ' order',
#   'orders': ' orders',
#   'other': ' other',
#   'our': ' our',
#   'out': ' out',
#   'over': ' over',
#   'own': ' own',
#   'owned': ' own',
#   'oysters': ' oyster',
#   'paced': ' pace',
#   'packed': ' packed',
#   'pains': ' pains',
#   'painted': ' paint',
#   'pairs': ' pair',
#   'pale': ' pale',
#   'paper': ' paper',
#   'parenthesis': ' parenthesis',
#   'part': ' part',
#   'particular': ' particular',
#   'passion': ' passion',
#   'peculiar': ' peculiar',
#   'pen': ' pen',
#   'pencil': ' pencil',
#   'pens': ' pen',
#   'perceived': ' perceive',
#   'perfect': ' perfect',
#   'perfectly': ' perfectly',
#   'perhaps': ' perhaps',
#   'perpetual': ' perpetual',
#   'perplexed': ' perplexed',
#   'pig': ' pig',
#   'pitiful': ' pitiful',
#   'place': ' place',
#   'plain': ' plain',
#   'plan': ' plan',
#   'plans': ' plan',
#   'pleased': ' pleased',
#   'poles': ' pole',
#   'policies': ' policy',
#   'poor': ' poor',
#   'popular': ' popular',
#   'portfolio': ' portfolio',
#   'possible': ' possible',
#   'praised': ' praise',
#   'preferred': ' prefer',
#   'preserve': ' preserve',
#   'pretence': ' pretence',
#   'pretend': ' pretend',
#   'pride': ' pride',
#   'principal': ' principal',
#   'proceed': ' proceed',
#   'proceeded': ' proceed',
#   'procure': ' procure',
#   'proof': ' proof',
#   'protest': ' protest',
#   'protested': ' protest',
#   'proved': ' prove',
#   'proving': ' prove',
#   'pun': ' pun',
#   'pursue': ' pursue',
#   'pursued': ' pursue',
#   'quarrels': ' quarrel',
#   'queer': ' queer',
#   'quite': ' quite',
#   'quivering': ' quiver',
#   'rack': ' rack',
#   'rapture': ' rapture',
#   'rather': ' rather',
#   'rations': ' rations',
#   'really': ' really',
#   'reason': ' reason',
#   'recalled': ' recall',
#   'reckoning': ' reckoning',
#   'recollecting': ' recollect',
#   'recurred': ' recur',
#   'remains': ' remains',
#   'remark': ' remark',
#   'remarked': ' remark',
#   'rent': ' rent',
#   'repays': ' repay',
#   'repeated': ' repeated',
#   'repetition': ' repetition',
#   'replied': ' reply',
#   'reply': ' reply',
#   'representing': ' represent',
#   'rest': ' rest',
#   'result': ' result',
#   'returned': ' return',
#   'returning': ' return',
#   'rig': ' rig',
#   'right': ' right',
#   'roused': ' rouse',
#   'rudder': ' rudder',
#   'ruff': ' ruff',
#   'sad': ' sad',
#   'sagaciously': ' sagaciously',
#   'said': ' say',
#   'sailed': ' sail',
#   'sailing': ' sailing',
#   'sailors': ' sailor',
#   'sale': ' sale',
#   'sally': ' sally',
#   'salt': ' salt',
#   'same': ' same',
#   'sat': ' sit',
#   'saved': ' save',
#   'saw': ' see',
#   'sawdust': ' sawdust',
#   'say': ' say',
#   'scarcely': ' scarcely',
#   'scared': ' scared',
#   'scenes': ' scene',
#   'scratch': ' scratch',
#   'scream': ' scream',
#   'scrupulous': ' scrupulous',
#   'sea': ' sea',
#   'season': ' season',
#   'second': ' second',
#   'second-hand': ' second-hand',
#   'see': ' see',
#   'seeing': ' seeing',
#   'seek': ' seek',
#   'seen': ' see',
#   'seldom': ' seldom',
#   'sentiment': ' sentiment',
#   'separate': ' separate',
#   'serve': ' serve',
#   'served': ' serve',
#   'set': ' set',
#   'seven': ' seven',
#   'seventeen': ' seventeen',
#   'seventy': ' seventy',
#   'shadowy': ' shadowy',
#   'shall': ' shall',
#   'shape': ' shape',
#   'shapes': ' shape',
#   'share': ' share',
#   'sharpening': ' sharpen',
#   'ship': ' ship',
#   'shook': ' shake',
#   'shortly': ' shortly',
#   'should': ' should',
#   'shoulder': ' shoulder',
#   'shriek': ' shriek',
#   'shrill': ' shrill',
#   'shuddering': ' shudder',
#   'shy': ' shy',
#   'sigh': ' sigh',
#   'sight': ' sight',
#   'sign': ' sign',
#   'signs': ' sign',
#   'silence': ' silence',
#   'silver': ' silver',
#   'simply': ' simply',
#   'since': ' since',
#   'sit': ' sit',
#   'skill': ' skill',
#   'skip': ' skip',
#   'sky': ' sky',
#   'slate': ' slate',
#   'slightest': ' slight',
#   'slowness': ' slowness',
#   'small': ' small',
#   'smiles': ' smile',
#   'so': ' so',
#   'soap': ' soap',
#   'sob': ' sob',
#   'society': ' society',
#   'soft': ' soft',
#   'softly': ' softly',
#   'solemnity': ' solemnity',
#   'some': ' some',
#   'somehow': ' somehow',
#   'sometimes': ' sometimes',
#   'song': ' song',
#   'sorrowful': ' sorrowful',
#   'sought': ' seek',
#   'soul': ' soul',
#   'sound': ' sound',
#   'spade': ' spade',
#   'speak': ' speak',
#   'speaks': ' speak',
#   'speech': ' speech',
#   'spent': ' spent',
#   'spirits': ' spirits',
#   'spite': ' spite',
#   'spoken': ' speak',
#   'spot': ' spot',
#   'squeaks': ' squeak',
#   'stands': ' stand',
#   'starboard': ' starboard',
#   'state': ' state',
#   'stated': ' stated',
#   'steer': ' steer',
#   'still': ' still',
#   'stood': ' stand',
#   'story': ' story',
#   'stout': ' stout',
#   'strange': ' strange',
#   'strength': ' strength',
#   'striking': ' striking',
#   'strongly': ' strongly',
#   'stuff': ' stuff',
#   'stupid': ' stupid',
#   'sty': ' sty',
#   'style': ' style',
#   'subject': ' subject',
#   'subscribe': ' subscribe',
#   'subtract': ' subtract',
#   'such': ' such',
#   'suddenly': ' suddenly',
#   'suggested': ' suggest',
#   'summer': ' summer',
#   'sums': ' sum',
#   'supplies': ' supply',
#   'supporting': ' support',
#   'supreme': ' supreme',
#   'sure': ' sure',
#   'surely': ' surely',
#   'surprise': ' surprise',
#   'symmetrical': ' symmetrical',
#   'take': ' take',
#   'taken': ' take',
#   'taking': ' taking',
#   'tale': ' tale',
#   'talked': ' talk',
#   'tame': ' tame',
#   'tape': ' tape',
#   'taste': ' taste',
#   'taught': ' teach',
#   'tears': ' tear',
#   'tell': ' tell',
#   'temper': ' temper',
#   'ten': ' ten',
#   'terms': ' terms',
#   'than': ' than',
#   'thank': ' thank',
#   'that': ' that',
#   "that's": " that's",
#   'the': ' the',
#   'their': ' their',
#   'them': ' them',
#   'then': ' then',
#   'there': ' there',
#   "there's": " there's",
#   'these': ' these',
#   'they': ' they',
#   'thimbles': ' thimble',
#   'thing': ' thing',
#   'things': ' things',
#   'think': ' think',
#   'thinking': ' thinking',
#   'third': ' third',
#   'this': ' this',
#   'those': ' those',
#   'though': ' though',
#   'thought': ' thought',
#   'thoughtful': ' thoughtful',
#   'thousand': ' thousand',
#   'threaten': ' threaten',
#   'threatened': ' threaten',
#   'three': ' three',
#   'thrice': ' thrice',
#   'thrill': ' thrill',
#   'thumbs': ' thumb',
#   'tight': ' tight',
#   'till': ' till',
#   'time': ' time',
#   'times': ' times',
#   'tingle': ' tingle',
#   'tingled': ' tingle',
#   'tip': ' tip',
#   'to': ' to',
#   'told': ' tell',
#   'tone': ' tone',
#   'too': ' too',
#   'took': ' take',
#   'top': ' top',
#   'travel': ' travel',
#   'tremendous': ' tremendous',
#   'tremulous': ' tremulous',
#   'tried': ' try',
#   'trip': ' trip',
#   'trite': ' trite',
#   'tropical': ' tropical',
#   'tropics': ' tropics',
#   'true': ' true',
#   'trusted': ' trust',
#   'try': ' try',
#   'turn': ' turn',
#   'turned': ' turn',
#   'twice': ' twice',
#   'two': ' two',
#   'umbrella': ' umbrella',
#   'unaccountably': ' unaccountably',
#   'uncle': ' uncle',
#   'understand': ' understand',
#   'undertaking': ' undertaking',
#   'unfailing': ' unfailing',
#   'unfrequented': ' unfrequented',
#   'unmanned': ' unmanned',
#   'unmistakable': ' unmistakable',
#   'unpacking': ' unpack',
#   'up': ' up',
#   'us': ' us',
#   'use': ' use',
#   'used': ' used',
#   'uttered': ' utter',
#   'vainly': ' vainly',
#   'valley': ' valley',
#   'value': ' value',
#   'vanish': ' vanish',
#   'venture': ' venture',
#   'very': ' very',
#   'vessel': ' vessel',
#   'vestige': ' vestige',
#   'vexes': ' vex',
#   'view': ' view',
#   'voice': ' voice',
#   'voyage': ' voyage',
#   'wag': ' wag',
#   'waist': ' waist',
#   'walk': ' walk',
#   'want': ' want',
#   'warranted': ' warrant',
#   'was': ' be',
#   'waste': ' waste',
#   'wasted': ' waste',
#   'watch': ' watch',
#   'watched': ' watch',
#   'way': ' way',
#   'we': ' we',
#   "we've": " we've",
#   'weak': ' weak',
#   'wearisome': ' wearisome',
#   'weary': ' weary',
#   'weather': ' weather',
#   'week': ' week',
#   'weeks': ' week',
#   'well': ' well',
#   'went': ' go',
#   'wept': ' weep',
#   'were': ' be',
#   'west': ' west',
#   'what': ' what',
#   "what's": " what's",
#   'when': ' when',
#   'whenever': ' whenever',
#   'where': ' where',
#   'wheresoever': ' wheresoever',
#   'which': ' which',
#   'while': ' while',
#   'whiskers': ' whiskers',
#   'who': ' who',
#   'whole': ' whole',
#   'wholly': ' wholly',
#   'whom': ' whom',
#   'whose': ' whose',
#   'wig': ' wig',
#   'will': ' will',
#   'wind': ' wind',
#   'wink': ' wink',
#   'winter': ' winter',
#   'wise': ' wise',
#   'with': ' with',
#   'without': ' without',
#   'witnesses': ' witness',
#   'won': ' win',
#   "won't": " won't",
#   'wondering': ' wonder',
#   'word': ' word',
#   'work': ' work',
#   'working': ' working',
#   'worst': ' worst',
#   'would': ' would',
#   'wrath': ' wrath',
#   'wreck': ' wreck',
#   'wrinkled': ' wrinkle',
#   'wrong': ' wrong',
#   'wrote': ' write',
#   'years': ' years',
#   'yellow': ' yellow',
#   'yet': ' yet',
#   'you': ' you',
#   "you'd": " you'd",
#   "you'll": " you'll",
#   "you've": " you've",
#   'your': ' your',
#   'yourselves': ' yourselves',
#   'zones': ' zone'},
#  ' Lemma CobMln': {'a': 23544,
#   'able': 328,
#   'aboard': 9,
#   'about': 2142,
#   'absolute': 42,
#   'absurd': 25,
#   'add': 234,
#   'added': 234,
#   'additional': 36,
#   'advised': 43,
#   'affectionate': 8,
#   'after': 762,
#   'again': 768,
#   'against': 586,
#   'ages': 290,
#   'agree': 191,
#   'ahead': 96,
#   'all': 3443,
#   'almost': 470,
#   'alone': 195,
#   'along': 188,
#   'already': 362,
#   'also': 920,
#   'although': 302,
#   'always': 661,
#   'am': 38301,
#   'ambition': 24,
#   'among': 284,
#   'amount': 155,
#   'amply': 2,
#   'an': 3309,
#   'and': 28705,
#   'angrily': 11,
#   'another': 700,
#   'answer': 170,
#   'antediluvian': 0,
#   'any': 1263,
#   'appeal': 53,
#   'appeared': 291,
#   'approach': 89,
#   'are': 38301,
#   'arrange': 88,
#   'arrangement': 62,
#   'art': 38301,
#   'as': 3044,
#   'asleep': 31,
#   'at': 5584,
#   'atone': 1,
#   'attempting': 78,
#   'attending': 75,
#   'away': 678,
#   'awkward': 20,
#   'bade': 5,
#   'bags': 80,
#   'bake': 24,
#   'baker': 17,
#   'bands': 45,
#   'banker': 14,
#   'barrister': 6,
#   'batch': 5,
#   'bathing-machines': 0,
#   'be': 38301,
#   'beach': 81,
#   'bear': 107,
#   'beauty': 58,
#   'beaver': 3,
#   'beavers': 3,
#   'became': 834,
#   'becomes': 834,
#   'been': 38301,
#   'before': 598,
#   'began': 683,
#   'beginning': 683,
#   'beheld': 5,
#   'behind': 287,
#   'being': 38301,
#   'believes': 426,
#   'bell': 42,
#   'best': 1451,
#   'betrayed': 20,
#   'beware': 5,
#   'bewilder': 14,
#   'billiard-marker': 0,
#   'billowy': 0,
#   'bird': 103,
#   'bite': 27,
#   'blank': 15,
#   'blew': 84,
#   'blissful': 1,
#   'board': 103,
#   'boil': 43,
#   'bold': 14,
#   'bonnets': 5,
#   'books': 434,
#   'boots': 39,
#   'bought': 256,
#   'bow': 16,
#   'bowl': 33,
#   'bowsprit': 0,
#   'boxes': 102,
#   'brains': 75,
#   'brave': 21,
#   'breakfasts': 55,
#   'brimming': 3,
#   'bring': 512,
#   'broke': 229,
#   'broker': 6,
#   'brought': 512,
#   'brow': 14,
#   'but': 5401,
#   'butcher': 6,
#   'by': 4337,
#   'call': 693,
#   'called': 693,
#   'came': 1960,
#   'can': 3954,
#   'cannot': 247,
#   'capes': 16,
#   'captain': 70,
#   'capture': 26,
#   'care': 121,
#   'carefully': 97,
#   'carriage': 16,
#   'carries': 311,
#   'cases': 495,
#   'cash': 50,
#   'caught': 193,
#   'caused': 171,
#   'cemented': 3,
#   'chalking': 1,
#   'chance': 172,
#   'changed': 459,
#   'charge': 95,
#   'charm': 22,
#   'charmed': 4,
#   'charming': 22,
#   'chasms': 3,
#   'check': 83,
#   'childhood': 43,
#   'chosen': 179,
#   'cite': 11,
#   'clear': 231,
#   'clearly': 143,
#   'climes': 1,
#   'clothes': 124,
#   'coat': 61,
#   'coats': 61,
#   'colder': 165,
#   'combed': 9,
#   'come': 1960,
#   'common': 188,
#   'commonplace': 6,
#   'complete': 87,
#   'concern': 74,
#   'condense': 4,
#   'confessed': 25,
#   'considered': 208,
#   'constantly': 40,
#   'contrived': 6,
#   'conundrums': 1,
#   'convenient': 24,
#   'conventional': 46,
#   'conveyed': 23,
#   'cooked': 72,
#   'costume': 30,
#   'could': 3954,
#   'count': 63,
#   'counted': 63,
#   'countrymen': 6,
#   'courage': 33,
#   'course': 729,
#   'court': 147,
#   'crags': 3,
#   'creature': 71,
#   'creatures': 71,
#   'creepy': 1,
#   'cress': 1,
#   'crew': 27,
#   'cried': 120,
#   'crimes': 65,
#   'crisp': 10,
#   'crossed': 75,
#   'crossing': 75,
#   'cry': 120,
#   'curds': 4,
#   'damage': 44,
#   'danger': 94,
#   'dark': 160,
#   'darker': 160,
#   'day': 893,
#   'days': 893,
#   'dear': 70,
#   'death': 239,
#   'debate': 45,
#   'deck': 20,
#   'declared': 55,
#   'decline': 33,
#   'deeply': 53,
#   'defending': 47,
#   'delight': 35,
#   'delirious': 3,
#   'delivered': 46,
#   'depend': 32,
#   'deplored': 7,
#   'describe': 164,
#   'deserted': 19,
#   'deserting': 19,
#   'desolate': 5,
#   'despair': 27,
#   'desperate': 31,
#   'did': 4499,
#   'difficult': 213,
#   'diminished': 26,
#   'dine': 31,
#   'dines': 31,
#   'disgust': 12,
#   'dismal': 5,
#   'displayed': 38,
#   'disputes': 29,
#   'distinguishing': 32,
#   'distressed': 10,
#   'divide': 64,
#   'do': 4499,
#   'does': 4499,
#   "don't": 1134,
#   'done': 4499,
#   'door': 386,
#   'doubt': 153,
#   'down': 1023,
#   'drank': 129,
#   'dread': 9,
#   'dream': 77,
#   'dreamed': 37,
#   'dreams': 77,
#   'dreamy': 4,
#   'dressed': 82,
#   'drove': 218,
#   'due': 91,
#   'dunce': 0,
#   'dust': 42,
#   'duty': 88,
#   'dwelt': 9,
#   'each': 631,
#   'earlier': 284,
#   'ears': 88,
#   'earth': 124,
#   'ease': 23,
#   'east': 32,
#   'effort': 137,
#   'eggs': 86,
#   'eight': 103,
#   'either': 248,
#   'eloquent': 4,
#   'embarked': 11,
#   'emotion': 58,
#   'employed': 62,
#   'encourage': 107,
#   'end': 434,
#   'endorsed': 10,
#   'endure': 19,
#   'enemies': 80,
#   'engage': 44,
#   'engaged': 44,
#   'engrossed': 3,
#   'enormous': 76,
#   'enough': 317,
#   'entered': 129,
#   'entirely': 103,
#   'entwined': 2,
#   'enveloped': 5,
#   'error': 31,
#   'especial': 1,
#   'especially': 173,
#   'even': 1307,
#   'evening': 202,
#   'ever': 449,
#   'every': 546,
#   'exactly': 141,
#   'excellent': 50,
#   'excessively': 6,
#   'excitedly': 5,
#   'exclaimed': 14,
#   'expense': 26,
#   'explain': 201,
#   'explained': 201,
#   'explaining': 201,
#   'exquisite': 9,
#   'extra': 71,
#   'eye': 523,
#   'eyes': 523,
#   'face': 460,
#   'fact': 571,
#   'failing': 145,
#   'fainted': 7,
#   'fairly': 83,
#   'false': 44,
#   'famed': 2,
#   'fancy': 16,
#   'far': 635,
#   'father': 300,
#   'feared': 79,
#   'feathers': 21,
#   'feel': 863,
#   'fell': 294,
#   'fellow': 44,
#   'felt': 863,
#   'ferociously': 1,
#   'fetch': 21,
#   'fifth': 17,
#   'fight': 142,
#   'find': 1088,
#   'finds': 1088,
#   'finger': 123,
#   'fingers': 123,
#   'fire': 162,
#   'first': 751,
#   'fit': 75,
#   'five': 291,
#   'fixed': 41,
#   'flavour': 19,
#   'flaw': 6,
#   'following': 296,
#   'fond': 23,
#   'fondness': 2,
#   'for': 7939,
#   'forbear': 1,
#   'forcible': 2,
#   'forgetting': 170,
#   'forgot': 170,
#   'forgotten': 170,
#   'forks': 15,
#   'form': 313,
#   'forty': 48,
#   'found': 1088,
#   'four': 326,
#   'fourth': 33,
#   'frequently': 58,
#   'friend': 356,
#   'friends': 356,
#   'friendship': 29,
#   'frightened': 36,
#   'fritter': 1,
#   'from': 4172,
#   'fry': 21,
#   'further': 635,
#   'galumphing': 0,
#   'gave': 1278,
#   'gaze': 31,
#   'genial': 2,
#   'genuine': 39,
#   'getting': 2381,
#   'give': 1278,
#   'giving': 1278,
#   'gladly': 6,
#   'glass': 145,
#   'glimpse': 20,
#   'glorious': 12,
#   'gloves': 19,
#   'glue': 3,
#   'go': 2889,
#   'going': 2889,
#   'good': 1451,
#   'goods': 52,
#   'got': 2381,
#   'gown': 12,
#   'grace': 22,
#   'grand': 49,
#   'grave': 21,
#   'gravely': 9,
#   'greens': 46,
#   'grew': 341,
#   'grieve': 5,
#   'grindstone': 1,
#   'groan': 11,
#   'grog': 1,
#   'grown': 341,
#   'guess': 77,
#   'habit': 63,
#   'had': 13494,
#   'hair': 199,
#   'hand': 724,
#   'handy': 8,
#   'happen': 437,
#   'happened': 437,
#   'happens': 437,
#   'hardly': 123,
#   'has': 13494,
#   'haste': 6,
#   'hasty': 4,
#   'have': 13494,
#   'he': 8828,
#   "he's": 207,
#   'head': 512,
#   'health': 132,
#   'hear': 505,
#   'heard': 505,
#   'heart': 164,
#   'heeded': 3,
#   'helmsman': 0,
#   'help': 388,
#   'her': 3847,
#   'hi': 9,
#   'high': 393,
#   'him': 2510,
#   'himself': 508,
#   'hire': 31,
#   'his': 5564,
#   'history': 190,
#   'hitherto': 10,
#   'ho': 7,
#   'hollow': 13,
#   'home': 340,
#   'honest': 36,
#   'hope': 227,
#   'hoped': 227,
#   'how': 732,
#   'howl': 10,
#   'hundred': 199,
#   'hunt': 29,
#   'hunting': 29,
#   'hyenas': 4,
#   'i': 11047,
#   'ice': 53,
#   'if': 3006,
#   'immense': 27,
#   'impudent': 1,
#   'in': 18464,
#   'included': 127,
#   'incredible': 19,
#   'indignantly': 3,
#   'informed': 37,
#   'infringement': 2,
#   'ingenious': 7,
#   'ink': 10,
#   'innocent': 37,
#   'instruction': 46,
#   'insure': 4,
#   'intellect': 8,
#   'interest': 287,
#   'intimate': 16,
#   'introduce': 91,
#   'introduction': 36,
#   'is': 38301,
#   'islands': 91,
#   'it': 11144,
#   "it's": 1012,
#   'its': 1549,
#   'ivory': 11,
#   'jam': 14,
#   'jewels': 9,
#   'joke': 50,
#   'jokes': 50,
#   'judge': 59,
#   'just': 1355,
#   'keep': 657,
#   'keeping': 657,
#   'keeps': 657,
#   'kegs': 1,
#   'kept': 657,
#   'kid': 79,
#   'kill': 209,
#   'knew': 2119,
#   'know': 2119,
#   'knows': 2119,
#   'lace': 13,
#   'landed': 29,
#   'landing': 29,
#   'larboard': 0,
#   'large': 437,
#   'last': 603,
#   'late': 629,
#   'laws': 224,
#   'learned': 308,
#   'least': 308,
#   'left': 783,
#   'leisure': 26,
#   'lend': 27,
#   'length': 83,
#   'lesson': 57,
#   'let': 431,
#   'liberal': 15,
#   'life': 833,
#   'light': 291,
#   'like': 1778,
#   'lines': 287,
#   'listen': 177,
#   'lives': 833,
#   'locusts': 2,
#   'long': 522,
#   'longer': 522,
#   'look': 1347,
#   'looked': 1347,
#   'looking': 1347,
#   'looks': 1347,
#   'loose': 38,
#   'lose': 339,
#   'loss': 98,
#   'lost': 339,
#   'loud': 30,
#   'lovingly': 5,
#   'low': 181,
#   'made': 2332,
#   'mahogany': 4,
#   'maker': 13,
#   'making': 2332,
#   'man': 1629,
#   'manner': 77,
#   'many': 967,
#   'map': 40,
#   'maps': 40,
#   'marched': 30,
#   'mark': 55,
#   'marks': 55,
#   'materials': 146,
#   'mattered': 90,
#   'maxim': 1,
#   'may': 1438,
#   'me': 2401,
#   'meagre': 6,
#   'meet': 233,
#   'men': 1629,
#   'mention': 113,
#   'merely': 118,
#   'meridian': 0,
#   'met': 233,
#   'method': 144,
#   'might': 1438,
#   'mildest': 28,
#   'mind': 335,
#   'mine': 79,
#   'minute': 283,
#   'mixed': 51,
#   'moderate': 12,
#   'moment': 333,
#   'month': 316,
#   'months': 316,
#   'more': 2858,
#   'mother': 474,
#   'much': 2858,
#   'musical': 23,
#   'must': 921,
#   'mustard': 5,
#   'mutton': 3,
#   'my': 2608,
#   'mystery': 31,
#   'name': 335,
#   'names': 335,
#   'narrow': 59,
#   'narrower': 59,
#   'natural': 157,
#   'navigation': 3,
#   'near': 113,
#   'need': 555,
#   'needs': 555,
#   'neither': 62,
#   'nephew': 9,
#   'nervous': 48,
#   'nervousness': 5,
#   'never': 896,
#   'next': 337,
#   'night': 463,
#   'nine': 74,
#   'ninety': 12,
#   'no': 1865,
#   'noble': 18,
#   'nodding': 79,
#   'none': 111,
#   'north': 45,
#   'not': 5099,
#   'note': 116,
#   'notes': 116,
#   'nothing': 503,
#   'notion': 47,
#   'novel': 40,
#   'now': 1726,
#   'number': 405,
#   'object': 104,
#   'occurred': 124,
#   'ocean': 29,
#   'of': 30106,
#   'off': 677,
#   'offered': 205,
#   'office': 281,
#   'often': 469,
#   'oh': 455,
#   'omitted': 10,
#   'on': 6083,
#   'once': 281,
#   'one': 2073,
#   'only': 1614,
#   'open': 230,
#   'opposite': 35,
#   'oppresses': 8,
#   'or': 4268,
#   'order': 289,
#   'orders': 289,
#   'other': 1638,
#   'our': 1284,
#   'out': 2526,
#   'over': 1007,
#   'own': 877,
#   'owned': 89,
#   'oysters': 7,
#   'paced': 11,
#   'packed': 38,
#   'pains': 84,
#   'painted': 72,
#   'pairs': 67,
#   'pale': 59,
#   'paper': 225,
#   'parenthesis': 1,
#   'part': 571,
#   'particular': 196,
#   'passion': 36,
#   'peculiar': 26,
#   'pen': 26,
#   'pencil': 19,
#   'pens': 26,
#   'perceived': 22,
#   'perfect': 63,
#   'perfectly': 66,
#   'perhaps': 473,
#   'perpetual': 8,
#   'perplexed': 3,
#   'pig': 43,
#   'pitiful': 4,
#   'place': 641,
#   'plain': 29,
#   'plan': 168,
#   'plans': 168,
#   'pleased': 45,
#   'poles': 21,
#   'policies': 226,
#   'poor': 208,
#   'popular': 80,
#   'portfolio': 6,
#   'possible': 336,
#   'praised': 17,
#   'preferred': 82,
#   'preserve': 40,
#   'pretence': 6,
#   'pretend': 52,
#   'pride': 39,
#   'principal': 28,
#   'proceed': 40,
#   'proceeded': 40,
#   'procure': 2,
#   'proof': 34,
#   'protest': 39,
#   'protested': 26,
#   'proved': 149,
#   'proving': 149,
#   'pun': 2,
#   'pursue': 44,
#   'pursued': 44,
#   'quarrels': 13,
#   'queer': 9,
#   'quite': 550,
#   'quivering': 11,
#   'rack': 10,
#   'rapture': 2,
#   'rather': 513,
#   'rations': 6,
#   'really': 592,
#   'reason': 327,
#   'recalled': 53,
#   'reckoning': 22,
#   'recollecting': 3,
#   'recurred': 7,
#   'remains': 262,
#   'remark': 39,
#   'remarked': 31,
#   'rent': 51,
#   'repays': 8,
#   'repeated': 66,
#   'repetition': 14,
#   'replied': 85,
#   'reply': 85,
#   'representing': 102,
#   'rest': 205,
#   'result': 221,
#   'returned': 221,
#   'returning': 221,
#   'rig': 5,
#   'right': 395,
#   'roused': 9,
#   'rudder': 1,
#   'ruff': 1,
#   'sad': 49,
#   'sagaciously': 0,
#   'said': 4267,
#   'sailed': 20,
#   'sailing': 20,
#   'sailors': 12,
#   'sale': 58,
#   'sally': 1,
#   'salt': 37,
#   'same': 660,
#   'sat': 500,
#   'saved': 122,
#   'saw': 2060,
#   'sawdust': 2,
#   'say': 4267,
#   'scarcely': 31,
#   'scared': 19,
#   'scenes': 111,
#   'scratch': 24,
#   'scream': 48,
#   'scrupulous': 1,
#   'sea': 173,
#   'season': 59,
#   'second': 258,
#   'second-hand': 5,
#   'see': 2060,
#   'seeing': 2060,
#   'seek': 120,
#   'seen': 2060,
#   'seldom': 33,
#   'sentiment': 12,
#   'separate': 60,
#   'serve': 149,
#   'served': 149,
#   'set': 314,
#   'seven': 119,
#   'seventeen': 19,
#   'seventy': 16,
#   'shadowy': 7,
#   'shall': 230,
#   'shape': 79,
#   'shapes': 79,
#   'share': 119,
#   'sharpening': 9,
#   'ship': 72,
#   'shook': 131,
#   'shortly': 36,
#   'should': 990,
#   'shoulder': 128,
#   'shriek': 12,
#   'shrill': 7,
#   'shuddering': 13,
#   'shy': 17,
#   'sigh': 30,
#   'sight': 101,
#   'sign': 139,
#   'signs': 139,
#   'silence': 90,
#   'silver': 51,
#   'simply': 232,
#   'since': 270,
#   'sit': 500,
#   'skill': 81,
#   'skip': 9,
#   'sky': 84,
#   'slate': 5,
#   'slightest': 52,
#   'slowness': 3,
#   'small': 600,
#   'smiles': 161,
#   'so': 2283,
#   'soap': 20,
#   'sob': 11,
#   'society': 338,
#   'soft': 82,
#   'softly': 25,
#   'solemnity': 2,
#   'some': 1832,
#   'somehow': 75,
#   'sometimes': 291,
#   'song': 50,
#   'sorrowful': 2,
#   'sought': 120,
#   'soul': 55,
#   'sound': 152,
#   'spade': 5,
#   'speak': 371,
#   'speaks': 371,
#   'speech': 93,
#   'spent': 281,
#   'spirits': 76,
#   'spite': 49,
#   'spoken': 371,
#   'spot': 55,
#   'squeaks': 4,
#   'stands': 467,
#   'starboard': 2,
#   'state': 323,
#   'stated': 50,
#   'steer': 15,
#   'still': 872,
#   'stood': 467,
#   'story': 228,
#   'stout': 9,
#   'strange': 106,
#   'strength': 97,
#   'striking': 111,
#   'strongly': 45,
#   'stuff': 65,
#   'stupid': 38,
#   'sty': 1,
#   'style': 105,
#   'subject': 182,
#   'subscribe': 5,
#   'subtract': 4,
#   'such': 941,
#   'suddenly': 188,
#   'suggested': 229,
#   'summer': 124,
#   'sums': 48,
#   'supplies': 72,
#   'supporting': 118,
#   'supreme': 23,
#   'sure': 263,
#   'surely': 76,
#   'surprise': 60,
#   'symmetrical': 4,
#   'take': 1913,
#   'taken': 1913,
#   'taking': 1913,
#   'tale': 32,
#   'talked': 510,
#   'tame': 4,
#   'tape': 34,
#   'taste': 57,
#   'taught': 143,
#   'tears': 61,
#   'tell': 1061,
#   'temper': 17,
#   'ten': 226,
#   'terms': 152,
#   'than': 1127,
#   'thank': 115,
#   'that': 7513,
#   "that's": 507,
#   'the': 59739,
#   'their': 2894,
#   'them': 2347,
#   'then': 1881,
#   'there': 3353,
#   "there's": 259,
#   'these': 1265,
#   'they': 4929,
#   'thimbles': 0,
#   'thing': 1037,
#   'things': 1037,
#   'think': 2000,
#   'thinking': 2000,
#   'third': 189,
#   'this': 4734,
#   'those': 882,
#   'though': 576,
#   'thought': 2000,
#   'thoughtful': 10,
#   'thousand': 113,
#   'threaten': 63,
#   'threatened': 63,
#   'three': 632,
#   'thrice': 1,
#   'thrill': 9,
#   'thumbs': 27,
#   'tight': 39,
#   'till': 38,
#   'time': 1971,
#   'times': 1971,
#   'tingle': 3,
#   'tingled': 3,
#   'tip': 30,
#   'to': 19942,
#   'told': 1061,
#   'tone': 53,
#   'too': 1042,
#   'took': 1913,
#   'top': 172,
#   'travel': 95,
#   'tremendous': 30,
#   'tremulous': 1,
#   'tried': 738,
#   'trip': 68,
#   'trite': 2,
#   'tropical': 19,
#   'tropics': 5,
#   'true': 250,
#   'trusted': 48,
#   'try': 738,
#   'turn': 578,
#   'turned': 578,
#   'twice': 55,
#   'two': 1369,
#   'umbrella': 14,
#   'unaccountably': 2,
#   'uncle': 66,
#   'understand': 291,
#   'undertaking': 30,
#   'unfailing': 1,
#   'unfrequented': 0,
#   'unmanned': 1,
#   'unmistakable': 6,
#   'unpacking': 5,
#   'up': 2000,
#   'us': 877,
#   'use': 798,
#   'used': 798,
#   'uttered': 14,
#   'vainly': 2,
#   'valley': 56,
#   'value': 173,
#   'vanish': 41,
#   'venture': 13,
#   'very': 1606,
#   'vessel': 17,
#   'vestige': 3,
#   'vexes': 2,
#   'view': 259,
#   'voice': 269,
#   'voyage': 9,
#   'wag': 4,
#   'waist': 21,
#   'walk': 309,
#   'want': 1119,
#   'warranted': 3,
#   'was': 38301,
#   'waste': 54,
#   'wasted': 38,
#   'watch': 250,
#   'watched': 250,
#   'way': 1318,
#   'we': 3615,
#   "we've": 128,
#   'weak': 59,
#   'wearisome': 1,
#   'weary': 10,
#   'weather': 65,
#   'week': 430,
#   'weeks': 430,
#   'well': 1100,
#   'went': 2889,
#   'wept': 28,
#   'were': 38301,
#   'west': 35,
#   'what': 2794,
#   "what's": 129,
#   'when': 2117,
#   'whenever': 51,
#   'where': 661,
#   'wheresoever': 0,
#   'which': 3423,
#   'while': 454,
#   'whiskers': 2,
#   'who': 2390,
#   'whole': 320,
#   'wholly': 29,
#   'whom': 180,
#   'whose': 223,
#   'wig': 13,
#   'will': 3858,
#   'wind': 120,
#   'wink': 8,
#   'winter': 83,
#   'wise': 40,
#   'with': 6966,
#   'without': 581,
#   'witnesses': 30,
#   'won': 154,
#   "won't": 173,
#   'wondering': 172,
#   'word': 492,
#   'work': 698,
#   'working': 553,
#   'worst': 330,
#   'would': 3858,
#   'wrath': 7,
#   'wreck': 10,
#   'wrinkled': 11,
#   'wrong': 172,
#   'wrote': 464,
#   'years': 1420,
#   'yellow': 52,
#   'yet': 281,
#   'you': 7174,
#   "you'd": 61,
#   "you'll": 121,
#   "you've": 199,
#   'your': 1612,
#   'yourselves': 8,
#   'zones': 16},
#  ' CobMln': {'a': 23543,
#   'able': 327,
#   'aboard': 9,
#   'about': 2142,
#   'absolute': 42,
#   'absurd': 25,
#   'add': 21,
#   'added': 22,
#   'additional': 36,
#   'advised': 4,
#   'affectionate': 8,
#   'after': 762,
#   'again': 768,
#   'against': 586,
#   'ages': 43,
#   'agree': 20,
#   'ahead': 96,
#   'all': 3443,
#   'almost': 470,
#   'alone': 195,
#   'along': 188,
#   'already': 362,
#   'also': 920,
#   'although': 302,
#   'always': 661,
#   'am': 349,
#   'ambition': 14,
#   'among': 284,
#   'amount': 127,
#   'amply': 2,
#   'an': 3309,
#   'and': 28705,
#   'angrily': 11,
#   'another': 700,
#   'answer': 102,
#   'antediluvian': 0,
#   'any': 1263,
#   'appeal': 46,
#   'appeared': 25,
#   'approach': 76,
#   'are': 2207,
#   'arrange': 7,
#   'arrangement': 28,
#   'art': 166,
#   'as': 3044,
#   'asleep': 31,
#   'at': 5584,
#   'atone': 0,
#   'attempting': 18,
#   'attending': 14,
#   'away': 678,
#   'awkward': 20,
#   'bade': 1,
#   'bags': 19,
#   'bake': 1,
#   'baker': 15,
#   'bands': 13,
#   'banker': 7,
#   'barrister': 4,
#   'batch': 4,
#   'bathing-machines': 0,
#   'be': 6214,
#   'beach': 59,
#   'bear': 13,
#   'beauty': 55,
#   'beaver': 2,
#   'beavers': 1,
#   'became': 67,
#   'becomes': 104,
#   'been': 2709,
#   'before': 598,
#   'began': 89,
#   'beginning': 94,
#   'beheld': 0,
#   'behind': 287,
#   'being': 814,
#   'believes': 29,
#   'bell': 27,
#   'best': 290,
#   'betrayed': 2,
#   'beware': 1,
#   'bewilder': 0,
#   'billiard-marker': 0,
#   'billowy': 0,
#   'bird': 42,
#   'bite': 10,
#   'blank': 15,
#   'blew': 5,
#   'blissful': 1,
#   'board': 85,
#   'boil': 7,
#   'bold': 11,
#   'bonnets': 1,
#   'books': 164,
#   'boots': 30,
#   'bought': 18,
#   'bow': 9,
#   'bowl': 26,
#   'bowsprit': 0,
#   'boxes': 24,
#   'brains': 11,
#   'brave': 19,
#   'breakfasts': 2,
#   'brimming': 1,
#   'bring': 45,
#   'broke': 16,
#   'broker': 3,
#   'brought': 50,
#   'brow': 10,
#   'but': 5401,
#   'butcher': 5,
#   'by': 4337,
#   'call': 50,
#   'called': 84,
#   'came': 174,
#   'can': 415,
#   'cannot': 247,
#   'capes': 1,
#   'captain': 63,
#   'capture': 5,
#   'care': 94,
#   'carefully': 97,
#   'carriage': 13,
#   'carries': 18,
#   'cases': 112,
#   'cash': 50,
#   'caught': 22,
#   'caused': 15,
#   'cemented': 0,
#   'chalking': 0,
#   'chance': 140,
#   'changed': 46,
#   'charge': 66,
#   'charm': 18,
#   'charmed': 1,
#   'charming': 22,
#   'chasms': 1,
#   'check': 21,
#   'childhood': 42,
#   'chosen': 59,
#   'cite': 1,
#   'clear': 221,
#   'clearly': 143,
#   'climes': 1,
#   'clothes': 124,
#   'coat': 50,
#   'coats': 11,
#   'colder': 5,
#   'combed': 1,
#   'come': 174,
#   'common': 180,
#   'commonplace': 6,
#   'complete': 87,
#   'concern': 64,
#   'condense': 0,
#   'confessed': 2,
#   'considered': 20,
#   'constantly': 40,
#   'contrived': 2,
#   'conundrums': 0,
#   'convenient': 24,
#   'conventional': 46,
#   'conveyed': 1,
#   'cooked': 5,
#   'costume': 20,
#   'could': 469,
#   'count': 41,
#   'counted': 3,
#   'countrymen': 4,
#   'courage': 33,
#   'course': 664,
#   'court': 124,
#   'crags': 1,
#   'creature': 35,
#   'creatures': 37,
#   'creepy': 1,
#   'cress': 1,
#   'crew': 21,
#   'cried': 10,
#   'crimes': 16,
#   'crisp': 10,
#   'crossed': 9,
#   'crossing': 13,
#   'cry': 19,
#   'curds': 1,
#   'damage': 44,
#   'danger': 74,
#   'dark': 149,
#   'darker': 9,
#   'day': 765,
#   'days': 263,
#   'dear': 65,
#   'death': 223,
#   'debate': 39,
#   'deck': 19,
#   'declared': 7,
#   'decline': 31,
#   'deeply': 53,
#   'defending': 10,
#   'delight': 23,
#   'delirious': 3,
#   'delivered': 5,
#   'depend': 32,
#   'deplored': 1,
#   'describe': 9,
#   'deserted': 3,
#   'deserting': 1,
#   'desolate': 5,
#   'despair': 27,
#   'desperate': 31,
#   'did': 292,
#   'difficult': 213,
#   'diminished': 2,
#   'dine': 1,
#   'dines': 1,
#   'disgust': 12,
#   'dismal': 5,
#   'displayed': 3,
#   'disputes': 11,
#   'distinguishing': 4,
#   'distressed': 2,
#   'divide': 4,
#   'do': 534,
#   'does': 488,
#   "don't": 1134,
#   'done': 398,
#   'door': 328,
#   'doubt': 133,
#   'down': 1023,
#   'drank': 9,
#   'dread': 6,
#   'dream': 48,
#   'dreamed': 3,
#   'dreams': 29,
#   'dreamy': 4,
#   'dressed': 12,
#   'drove': 16,
#   'due': 91,
#   'dunce': 0,
#   'dust': 42,
#   'duty': 65,
#   'dwelt': 0,
#   'each': 631,
#   'earlier': 80,
#   'ears': 46,
#   'earth': 123,
#   'ease': 23,
#   'east': 32,
#   'effort': 87,
#   'eggs': 49,
#   'eight': 103,
#   'either': 248,
#   'eloquent': 4,
#   'embarked': 1,
#   'emotion': 28,
#   'employed': 7,
#   'encourage': 9,
#   'end': 406,
#   'endorsed': 1,
#   'endure': 3,
#   'enemies': 31,
#   'engage': 3,
#   'engaged': 10,
#   'engrossed': 1,
#   'enormous': 76,
#   'enough': 317,
#   'entered': 11,
#   'entirely': 103,
#   'entwined': 0,
#   'enveloped': 0,
#   'error': 20,
#   'especial': 1,
#   'especially': 173,
#   'even': 1307,
#   'evening': 183,
#   'ever': 449,
#   'every': 546,
#   'exactly': 141,
#   'excellent': 50,
#   'excessively': 6,
#   'excitedly': 5,
#   'exclaimed': 2,
#   'expense': 26,
#   'explain': 21,
#   'explained': 16,
#   'explaining': 21,
#   'exquisite': 9,
#   'extra': 71,
#   'eye': 127,
#   'eyes': 396,
#   'face': 401,
#   'fact': 509,
#   'failing': 16,
#   'fainted': 1,
#   'fairly': 83,
#   'false': 44,
#   'famed': 2,
#   'fancy': 14,
#   'far': 473,
#   'father': 272,
#   'feared': 6,
#   'feathers': 16,
#   'feel': 87,
#   'fell': 27,
#   'fellow': 33,
#   'felt': 81,
#   'ferociously': 1,
#   'fetch': 3,
#   'fifth': 17,
#   'fight': 31,
#   'find': 129,
#   'finds': 35,
#   'finger': 48,
#   'fingers': 75,
#   'fire': 146,
#   'first': 751,
#   'fit': 18,
#   'five': 291,
#   'fixed': 41,
#   'flavour': 17,
#   'flaw': 4,
#   'following': 66,
#   'fond': 22,
#   'fondness': 2,
#   'for': 7939,
#   'forbear': 0,
#   'forcible': 2,
#   'forgetting': 9,
#   'forgot': 6,
#   'forgotten': 58,
#   'forks': 3,
#   'form': 225,
#   'forty': 48,
#   'found': 96,
#   'four': 326,
#   'fourth': 33,
#   'frequently': 58,
#   'friend': 172,
#   'friends': 184,
#   'friendship': 24,
#   'frightened': 36,
#   'fritter': 0,
#   'from': 4172,
#   'fry': 1,
#   'further': 139,
#   'galumphing': 0,
#   'gave': 72,
#   'gaze': 15,
#   'genial': 2,
#   'genuine': 39,
#   'getting': 245,
#   'give': 121,
#   'giving': 127,
#   'gladly': 6,
#   'glass': 125,
#   'glimpse': 16,
#   'glorious': 12,
#   'gloves': 15,
#   'glue': 3,
#   'go': 258,
#   'going': 799,
#   'good': 941,
#   'goods': 52,
#   'got': 172,
#   'gown': 9,
#   'grace': 21,
#   'grand': 44,
#   'grave': 15,
#   'gravely': 9,
#   'greens': 6,
#   'grew': 18,
#   'grieve': 0,
#   'grindstone': 0,
#   'groan': 2,
#   'grog': 1,
#   'grown': 49,
#   'guess': 13,
#   'habit': 39,
#   'had': 1248,
#   'hair': 191,
#   'hand': 440,
#   'handy': 8,
#   'happen': 29,
#   'happened': 38,
#   'happens': 76,
#   'hardly': 123,
#   'has': 2118,
#   'haste': 6,
#   'hasty': 4,
#   'have': 1192,
#   'he': 8828,
#   "he's": 207,
#   'head': 223,
#   'health': 132,
#   'hear': 47,
#   'heard': 57,
#   'heart': 145,
#   'heeded': 0,
#   'helmsman': 0,
#   'help': 135,
#   'her': 3847,
#   'hi': 9,
#   'high': 269,
#   'him': 2510,
#   'himself': 508,
#   'hire': 5,
#   'his': 5564,
#   'history': 187,
#   'hitherto': 10,
#   'ho': 7,
#   'hollow': 13,
#   'home': 295,
#   'honest': 36,
#   'hope': 57,
#   'hoped': 12,
#   'how': 732,
#   'howl': 1,
#   'hundred': 199,
#   'hunt': 11,
#   'hunting': 29,
#   'hyenas': 2,
#   'i': 11045,
#   'ice': 52,
#   'if': 3006,
#   'immense': 27,
#   'impudent': 1,
#   'in': 18464,
#   'included': 9,
#   'incredible': 19,
#   'indignantly': 3,
#   'informed': 9,
#   'infringement': 1,
#   'ingenious': 7,
#   'ink': 9,
#   'innocent': 37,
#   'instruction': 16,
#   'insure': 0,
#   'intellect': 7,
#   'interest': 213,
#   'intimate': 16,
#   'introduce': 6,
#   'introduction': 34,
#   'is': 9435,
#   'islands': 24,
#   'it': 11144,
#   "it's": 1012,
#   'its': 1549,
#   'ivory': 11,
#   'jam': 12,
#   'jewels': 6,
#   'joke': 33,
#   'jokes': 17,
#   'judge': 41,
#   'just': 1355,
#   'keep': 87,
#   'keeping': 67,
#   'keeps': 32,
#   'kegs': 0,
#   'kept': 42,
#   'kid': 29,
#   'kill': 19,
#   'knew': 114,
#   'know': 339,
#   'knows': 129,
#   'lace': 10,
#   'landed': 4,
#   'landing': 16,
#   'larboard': 0,
#   'large': 326,
#   'last': 603,
#   'late': 179,
#   'laws': 58,
#   'learned': 18,
#   'least': 308,
#   'left': 84,
#   'leisure': 26,
#   'lend': 3,
#   'length': 72,
#   'lesson': 27,
#   'let': 44,
#   'liberal': 15,
#   'life': 735,
#   'light': 234,
#   'like': 1778,
#   'lines': 77,
#   'listen': 19,
#   'lives': 98,
#   'locusts': 2,
#   'long': 474,
#   'longer': 188,
#   'look': 130,
#   'looked': 102,
#   'looking': 303,
#   'looks': 100,
#   'loose': 36,
#   'lose': 20,
#   'loss': 78,
#   'lost': 42,
#   'loud': 23,
#   'lovingly': 5,
#   'low': 124,
#   'made': 199,
#   'mahogany': 4,
#   'maker': 5,
#   'making': 274,
#   'man': 975,
#   'manner': 76,
#   'many': 967,
#   'map': 30,
#   'maps': 10,
#   'marched': 3,
#   'mark': 30,
#   'marks': 25,
#   'materials': 50,
#   'mattered': 2,
#   'maxim': 0,
#   'may': 203,
#   'me': 2401,
#   'meagre': 6,
#   'meet': 87,
#   'men': 655,
#   'mention': 12,
#   'merely': 118,
#   'meridian': 0,
#   'met': 30,
#   'method': 77,
#   'might': 106,
#   'mildest': 1,
#   'mind': 294,
#   'mine': 79,
#   'minute': 74,
#   'mixed': 26,
#   'moderate': 12,
#   'moment': 333,
#   'month': 90,
#   'months': 226,
#   'more': 1219,
#   'mother': 410,
#   'much': 783,
#   'musical': 23,
#   'must': 184,
#   'mustard': 5,
#   'mutton': 3,
#   'my': 2608,
#   'mystery': 24,
#   'name': 264,
#   'names': 71,
#   'narrow': 53,
#   'narrower': 4,
#   'natural': 157,
#   'navigation': 3,
#   'near': 113,
#   'need': 167,
#   'needs': 95,
#   'neither': 62,
#   'nephew': 8,
#   'nervous': 48,
#   'nervousness': 5,
#   'never': 896,
#   'next': 337,
#   'night': 428,
#   'nine': 74,
#   'ninety': 12,
#   'no': 1865,
#   'noble': 16,
#   'nodding': 9,
#   'none': 111,
#   'north': 45,
#   'not': 5099,
#   'note': 66,
#   'notes': 50,
#   'nothing': 503,
#   'notion': 36,
#   'novel': 28,
#   'now': 1726,
#   'number': 319,
#   'object': 56,
#   'occurred': 11,
#   'ocean': 24,
#   'of': 30106,
#   'off': 677,
#   'offered': 19,
#   'office': 249,
#   'often': 469,
#   'oh': 455,
#   'omitted': 1,
#   'on': 6083,
#   'once': 281,
#   'one': 1931,
#   'only': 1614,
#   'open': 212,
#   'opposite': 35,
#   'oppresses': 0,
#   'or': 4268,
#   'order': 244,
#   'orders': 45,
#   'other': 1638,
#   'our': 1284,
#   'out': 2526,
#   'over': 1007,
#   'own': 877,
#   'owned': 7,
#   'oysters': 3,
#   'paced': 1,
#   'packed': 9,
#   'pains': 8,
#   'painted': 9,
#   'pairs': 12,
#   'pale': 56,
#   'paper': 174,
#   'parenthesis': 1,
#   'part': 466,
#   'particular': 196,
#   'passion': 31,
#   'peculiar': 26,
#   'pen': 19,
#   'pencil': 15,
#   'pens': 7,
#   'perceived': 2,
#   'perfect': 63,
#   'perfectly': 66,
#   'perhaps': 473,
#   'perpetual': 8,
#   'perplexed': 3,
#   'pig': 18,
#   'pitiful': 4,
#   'place': 523,
#   'plain': 28,
#   'plan': 72,
#   'plans': 63,
#   'pleased': 45,
#   'poles': 10,
#   'policies': 59,
#   'poor': 189,
#   'popular': 80,
#   'portfolio': 5,
#   'possible': 336,
#   'praised': 2,
#   'preferred': 6,
#   'preserve': 4,
#   'pretence': 5,
#   'pretend': 6,
#   'pride': 38,
#   'principal': 28,
#   'proceed': 4,
#   'proceeded': 3,
#   'procure': 0,
#   'proof': 30,
#   'protest': 29,
#   'protested': 3,
#   'proved': 13,
#   'proving': 9,
#   'pun': 1,
#   'pursue': 4,
#   'pursued': 3,
#   'quarrels': 5,
#   'queer': 9,
#   'quite': 550,
#   'quivering': 7,
#   'rack': 8,
#   'rapture': 2,
#   'rather': 513,
#   'rations': 4,
#   'really': 592,
#   'reason': 226,
#   'recalled': 4,
#   'reckoning': 3,
#   'recollecting': 0,
#   'recurred': 0,
#   'remains': 43,
#   'remark': 19,
#   'remarked': 4,
#   'rent': 37,
#   'repays': 0,
#   'repeated': 13,
#   'repetition': 10,
#   'replied': 13,
#   'reply': 29,
#   'representing': 14,
#   'rest': 203,
#   'result': 156,
#   'returned': 22,
#   'returning': 32,
#   'rig': 4,
#   'right': 395,
#   'roused': 1,
#   'rudder': 1,
#   'ruff': 1,
#   'sad': 46,
#   'sagaciously': 0,
#   'said': 554,
#   'sailed': 2,
#   'sailing': 5,
#   'sailors': 6,
#   'sale': 34,
#   'sally': 0,
#   'salt': 35,
#   'same': 660,
#   'sat': 46,
#   'saved': 7,
#   'saw': 97,
#   'sawdust': 2,
#   'say': 219,
#   'scarcely': 31,
#   'scared': 19,
#   'scenes': 23,
#   'scratch': 5,
#   'scream': 5,
#   'scrupulous': 1,
#   'sea': 160,
#   'season': 49,
#   'second': 258,
#   'second-hand': 5,
#   'see': 292,
#   'seeing': 84,
#   'seek': 11,
#   'seen': 376,
#   'seldom': 33,
#   'sentiment': 8,
#   'separate': 60,
#   'serve': 16,
#   'served': 11,
#   'set': 82,
#   'seven': 119,
#   'seventeen': 19,
#   'seventy': 16,
#   'shadowy': 7,
#   'shall': 46,
#   'shape': 62,
#   'shapes': 18,
#   'share': 39,
#   'sharpening': 2,
#   'ship': 44,
#   'shook': 17,
#   'shortly': 36,
#   'should': 198,
#   'shoulder': 67,
#   'shriek': 3,
#   'shrill': 6,
#   'shuddering': 4,
#   'shy': 17,
#   'sigh': 12,
#   'sight': 94,
#   'sign': 87,
#   'signs': 52,
#   'silence': 87,
#   'silver': 51,
#   'simply': 232,
#   'since': 270,
#   'sit': 30,
#   'skill': 38,
#   'skip': 1,
#   'sky': 77,
#   'slate': 4,
#   'slightest': 17,
#   'slowness': 3,
#   'small': 521,
#   'smiles': 9,
#   'so': 2283,
#   'soap': 20,
#   'sob': 1,
#   'society': 278,
#   'soft': 78,
#   'softly': 25,
#   'solemnity': 2,
#   'some': 1832,
#   'somehow': 75,
#   'sometimes': 291,
#   'song': 33,
#   'sorrowful': 2,
#   'sought': 7,
#   'soul': 41,
#   'sound': 123,
#   'spade': 3,
#   'speak': 32,
#   'speaks': 15,
#   'speech': 76,
#   'spent': 28,
#   'spirits': 17,
#   'spite': 49,
#   'spoken': 42,
#   'spot': 40,
#   'squeaks': 1,
#   'stands': 33,
#   'starboard': 2,
#   'state': 290,
#   'stated': 5,
#   'steer': 1,
#   'still': 872,
#   'stood': 42,
#   'story': 167,
#   'stout': 9,
#   'strange': 101,
#   'strength': 91,
#   'striking': 18,
#   'strongly': 45,
#   'stuff': 64,
#   'stupid': 37,
#   'sty': 1,
#   'style': 86,
#   'subject': 125,
#   'subscribe': 1,
#   'subtract': 1,
#   'such': 941,
#   'suddenly': 188,
#   'suggested': 19,
#   'summer': 121,
#   'sums': 17,
#   'supplies': 15,
#   'supporting': 20,
#   'supreme': 23,
#   'sure': 261,
#   'surely': 76,
#   'surprise': 56,
#   'symmetrical': 4,
#   'take': 192,
#   'taken': 338,
#   'taking': 210,
#   'tale': 17,
#   'talked': 19,
#   'tame': 4,
#   'tape': 28,
#   'taste': 48,
#   'taught': 13,
#   'tears': 55,
#   'tell': 112,
#   'temper': 15,
#   'ten': 226,
#   'terms': 152,
#   'than': 1127,
#   'thank': 25,
#   'that': 7513,
#   "that's": 507,
#   'the': 59739,
#   'their': 2894,
#   'them': 2347,
#   'then': 1881,
#   'there': 3353,
#   "there's": 259,
#   'these': 1265,
#   'they': 4929,
#   'thimbles': 0,
#   'thing': 542,
#   'things': 495,
#   'think': 305,
#   'thinking': 137,
#   'third': 189,
#   'this': 4734,
#   'those': 882,
#   'though': 576,
#   'thought': 129,
#   'thoughtful': 10,
#   'thousand': 113,
#   'threaten': 3,
#   'threatened': 8,
#   'three': 632,
#   'thrice': 1,
#   'thrill': 5,
#   'thumbs': 4,
#   'tight': 34,
#   'till': 38,
#   'time': 1789,
#   'times': 182,
#   'tingle': 0,
#   'tingled': 0,
#   'tip': 19,
#   'to': 19942,
#   'told': 98,
#   'tone': 44,
#   'too': 1042,
#   'took': 119,
#   'top': 161,
#   'travel': 29,
#   'tremendous': 30,
#   'tremulous': 1,
#   'tried': 42,
#   'trip': 54,
#   'trite': 1,
#   'tropical': 19,
#   'tropics': 5,
#   'true': 248,
#   'trusted': 3,
#   'try': 67,
#   'turn': 94,
#   'turned': 65,
#   'twice': 55,
#   'two': 1369,
#   'umbrella': 11,
#   'unaccountably': 2,
#   'uncle': 59,
#   'understand': 50,
#   'undertaking': 4,
#   'unfailing': 1,
#   'unfrequented': 0,
#   'unmanned': 1,
#   'unmistakable': 6,
#   'unpacking': 1,
#   'up': 2000,
#   'us': 877,
#   'use': 213,
#   'used': 74,
#   'uttered': 2,
#   'vainly': 2,
#   'valley': 49,
#   'value': 115,
#   'vanish': 1,
#   'venture': 7,
#   'very': 1606,
#   'vessel': 9,
#   'vestige': 1,
#   'vexes': 0,
#   'view': 209,
#   'voice': 232,
#   'voyage': 8,
#   'wag': 0,
#   'waist': 20,
#   'walk': 43,
#   'want': 163,
#   'warranted': 0,
#   'was': 5417,
#   'waste': 42,
#   'wasted': 3,
#   'watch': 37,
#   'watched': 19,
#   'way': 1178,
#   'we': 3615,
#   "we've": 128,
#   'weak': 47,
#   'wearisome': 1,
#   'weary': 10,
#   'weather': 65,
#   'week': 271,
#   'weeks': 159,
#   'well': 843,
#   'went': 173,
#   'wept': 2,
#   'were': 1177,
#   'west': 35,
#   'what': 2794,
#   "what's": 129,
#   'when': 2117,
#   'whenever': 51,
#   'where': 661,
#   'wheresoever': 0,
#   'which': 3423,
#   'while': 454,
#   'whiskers': 2,
#   'who': 2390,
#   'whole': 320,
#   'wholly': 29,
#   'whom': 180,
#   'whose': 223,
#   'wig': 7,
#   'will': 388,
#   'wind': 106,
#   'wink': 3,
#   'winter': 79,
#   'wise': 32,
#   'with': 6966,
#   'without': 581,
#   'witnesses': 15,
#   'won': 14,
#   "won't": 173,
#   'wondering': 36,
#   'word': 220,
#   'work': 666,
#   'working': 196,
#   'worst': 37,
#   'would': 480,
#   'wrath': 7,
#   'wreck': 6,
#   'wrinkled': 2,
#   'wrong': 172,
#   'wrote': 32,
#   'years': 913,
#   'yellow': 52,
#   'yet': 281,
#   'you': 7174,
#   "you'd": 61,
#   "you'll": 121,
#   "you've": 199,
#   'your': 1612,
#   'yourselves': 8,
#   'zones': 5}}

# %%
df['CobMln'] = df.token.apply(lambda x: freq_dict[' CobMln'].get(x, 1))

# %%
df.to_csv('freq_result.csv')
