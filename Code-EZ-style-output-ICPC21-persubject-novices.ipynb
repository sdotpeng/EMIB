# %%
from numpy import mean, sum

# %%
class Word:
    #class for word data
    def __init__(self, file, line_part, text):
        
        self._file = file
        
        tokenized_line_part = line_part.split()
        self._line = int(tokenized_line_part[1])
        self._part = int(tokenized_line_part[3])
        self._text = text
        
        self._participants = []
        self._durations = []
        self._start_times = []
        self._length = -1
        self._freq = -1
        self._predict = -1
        
        
    def add(self, participant, duration, start_time, length, freq, predict, level):
        
        self._participants.append(participant)
        self._durations.append(int(duration))
        self._start_times.append(int(start_time))
        self._length = int(float(length))
        self._freq = int(float(freq))
        self._predict = float(predict)
        self._level = level
        
    
    def get_basic_info(self):
        
        return self._file + "  " +\
        str(self._line) + "  " +\
        str(self._part) + "  " +\
        self._text + "  " +\
        str(self._participants) + "  " +\
        str(self._durations) + "  " +\
        str(self._start_times) + "  " +\
        str(self._length) + "  " +\
        str(self._freq) + "  " +\
        str(self._predict)
        
    def get_text(self):
        return self._text
    
    def get_freq(self):
        return self._freq
    
    def get_pred(self):
        return round(self._predict, 2)
    
    def get_leng(self):
        return self._length
    
    def get_subject(self):
        return self._participants[0]
    
    def get_level(self):
        return self._level
        
        
    def single_fix_duration(self):
        #duration of first_fixation with cases where only one fixation is made.
        result = []

        for index, person in enumerate(self._participants):
            if self._is_unique(person, self._participants):
                result.append(self._durations[index])

        return round(mean(result), 2)


    def first_fix_duration(self):
        #duration of first fixation on word.
        fixations_durations = []
        
        for person in self._unique_participants():
            fixations_durations.append(self._durations[self._find_first_fix(self._get_index_of_person_fixations(person))])
        
        return round(mean(fixations_durations), 2)
        

    def gaze_duration(self):
        #sum of all fixations on word n before moving to n+1.
        gaze_durations = []
        
        for person in self._unique_participants():
            gaze_durations.append(self._person_gaze_duation(self._get_index_of_person_fixations(person)))
        
        return round(mean(gaze_durations), 2)


    def total_time(self):
        #sum of all fixations and regressions.
        return round(sum(self._durations) / len(self._unique_participants()), 2)


    def fix_probability(self):
        #count of participants who made at least one fixation / count of participants in experiment
        return round(len(self._unique_participants()) / len(participants[self._file]), 2)


    def prob_of_one_fix(self):
        # count of participants who made only one fixation / count of participants in experiment
        count = 0

        for person in self._unique_participants():
            if self._is_unique(person, self._participants):
                count += 1

        return round(count / len(participants[self._file]), 2)


    def prob_of_2_or_more_fix(self):
        # count of participants who made 2 or more fixations / count of participants in experiment
        count = 0

        for person in self._unique_participants():
            if not self._is_unique(person, self._participants):
                count += 1

        return round(count / len(participants[self._file]), 2)


    def prob_of_skip(self):
        # count of participants who didn't make a fixation / count of participants in experiment

        skipper = 0

        for person in participants[self._file]:
            if person not in self._unique_participants():
                skipper += 1

        return round(skipper / len(participants[self._file]), 2)


    def _unique_participants(self):
        #returns the list of participants without repetition
        result = []

        for person in self._participants:
            if person not in result:
                result.append(person)

        return result


    def _is_unique(self, item, some_list):
        #returns true if there is only one of item in some_list
        count = 0

        for val in some_list:
            if val == item:
                count += 1

        if count == 1:
            return True
        return False
    
    
    def _get_index_of_person_fixations(self, someone):
        #returns the indexes of all fixations for one person
        
        result = []
        for index, person in enumerate(self._participants):
            if person == someone:
                result.append(index)
                
        return result
    
    def _find_first_fix(self, list_of_fix_indexes):
        #returns the index of the first fixation (temporaly)
        
        result = list_of_fix_indexes[0]
        first_fix = self._start_times[list_of_fix_indexes[0]]
        
        for index in list_of_fix_indexes:
            if self._start_times[index] < first_fix:
                first_fix = self._start_times[index]
                result = index
                
        return result
        
        
    def _person_gaze_duation(self, list_of_fix_indexes):
        #sum of all fixations on word n before moving to n+1.
        fix_durations = []
        
        time = self._start_times[list_of_fix_indexes[0]]
        
        for fix_index in list_of_fix_indexes:
            if self._start_times[fix_index] - time < 100:
                fix_durations.append(self._durations[fix_index])
                time = self._start_times[fix_index]
            
        return sum(fix_durations)

# %%
#testing all of my methods
#nt1,line 1 part 1
my_word = Word("nt1", "line 1 part 1", "test_word")

#participant, duration, start_time, length, freq, predict
my_word.add("1", "100", "10", "11", "55.0", "0.0555", "1")
my_word.add("1", "200", "15", "11", "55.0", "0.0555", "1")
my_word.add("1", "300", "125", "11", "55.0", "0.0555", "1")
my_word.add("2", "200", "10", "11", "55.0", "0.0555", "2")
my_word.add("2", "250", "20", "11", "55.0", "0.0555", "2")
my_word.add("3", "300", "100", "11", "55.0", "0.0555", "3")

participants = {}
participants["nt1"] = ["1", "2", "3", "4"]

print("single_fix_duration", my_word.single_fix_duration(), "\tshould print: 300")
print("first_fix_duration", my_word.first_fix_duration(), "\tshould print: 200")
print("gaze_duration", my_word.gaze_duration(), "\tshould print: 350") 
print("total_time", my_word.total_time(), "\tshould print: 450.0")
print("fix_probability", my_word.fix_probability(), "\tshould print: 0.75")
print("prob_of_one_fix", my_word.prob_of_one_fix(), "\tshould print: 0.25")
print("prob_of_2_or_more_fix", my_word.prob_of_2_or_more_fix(), "\tshould print: 0.5")
print("prob_of_skip", my_word.prob_of_skip(), "\tshould print: 0.25")
# Out:
# single_fix_duration 300.0 	should print: 300
# first_fix_duration 200.0 	should print: 200
# gaze_duration 350.0 	should print: 350
# total_time 450.0 	should print: 450.0
# fix_probability 0.75 	should print: 0.75
# prob_of_one_fix 0.25 	should print: 0.25
# prob_of_2_or_more_fix 0.5 	should print: 0.5
# prob_of_skip 0.25 	should print: 0.25

# %%
#dictionary of all words
#file + line_part as key and word object as value
lexicon = {}

#dictionary to list all participants in each experiment (or file)
participants = {}

#open out.csv and read in each record
file = open('Novice-code-filtered.csv', 'rt')

text = file.read()
file.close()
lines = text.split('\n')
skip_next_word = False

line_num = 0
for line in lines[:-1]:
    line_num += 1
    print(line_num, line)
    
    if skip_next_word:         #to skip next word after '.'
        skip_next_word = False
        continue
        
    if line_num == 1: continue #skip header
        
    tokens = line.split(',')
    
    line_part = tokens[1].split()
    
    if line_part[1] == line_part[3] == "1": #skipping first word in first sentence in file
        continue
    
    if tokens[25][-1] ==';': #skipping last word in each sentence
        skip_next_word = True
        continue
    
    #dictionary of words based on file, line-part, and subject
    if lexicon.get(tokens[0] + tokens[1] + tokens[2], 0) == 0:
        lexicon[tokens[0] + tokens[1] + tokens[2]] = Word(tokens[0], tokens[1], tokens[25]) #file, line_part, text
    
    #participant, duration, start_time, len, freq, predict 
    lexicon[tokens[0] + tokens[1] + tokens[2]].add(tokens[2], tokens[7], tokens[8], tokens[27], tokens[28], tokens[29], tokens[0])

    #participants dictionary
    if participants.get(tokens[0], 0) == 0:
        participants[tokens[0]] = []
        
    #if participant not already in the list for that file: to get unique values in the list
    if tokens[2] not in participants[tokens[0]]:
        participants[tokens[0]].append(tokens[2])
# Out:
# 1 trial,aoi_sub_line,participant,text_type,text_nr,fix_x,fix_y,duration_ms,start_ms,end_ms,fix_x_original,fix_y_original,exp_id,trial_id,program,offset_kind,aoi_line,is_expert,kind,name,x,y,width,height,local_id,wordl1_sc1,line 1 part 1,6,sc,1
# 2 l1_sc1,line 1 part 1,4,sc,1,406,355,142,617,759,406,355,1,4,sc1,0,line 1,0,sub-line,line 1 part 1,582,357,65,50,,public,public,6,19831.13901,0.042731726
# 3 l1_sc1,line 1 part 1,4,sc,1,407,394,242,125,367,407,394,1,4,sc1,0,line 1,0,sub-line,line 1 part 1,582,357,65,50,,public,public,6,19831.13901,0.042731726
# 4 l1_sc1,line 1 part 1,8,sc,1,634,404,250,250,500,634,404,1,8,sc1,0,line 1,0,sub-line,line 1 part 1,582,357,65,50,,public,public,6,19831.13901,0.042731726
# 5 l1_sc1,line 1 part 1,4,sc,1,411,370,250,12724,12974,411,370,1,4,sc1,0,line 1,0,sub-line,line 1 part 1,582,357,65,50,,public,public,6,19831.13901,0.042731726
# 6 l1_sc1,line 1 part 1,4,sc,1,429,366,234,375,609,429,366,1,4,sc1,0,line 1,0,sub-line,line 1 part 1,582,357,65,50,,public,public,6,19831.13901,0.042731726
# 7 l1_sc1,line 1 part 1,7,sc,1,637,360,167,1076,1243,682,355,1,7,sc1,0,line 1,0,sub-line,line 1 part 1,582,357,65,50,,public,public,6,19831.13901,0.042731726
# 8 l1_sc1,line 1 part 2,13,sc,1,660,391,242,642,884,660,391,1,13,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 9 l1_sc1,line 1 part 2,11,sc,1,702,395,150,2219,2369,702,510,1,11,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 10 l1_sc1,line 1 part 2,4,sc,1,463,367,384,767,1151,463,367,1,4,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 11 l1_sc1,line 1 part 2,4,sc,1,460,372,292,12982,13274,460,372,1,4,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 12 l1_sc1,line 1 part 2,8,sc,1,672,382,184,1184,1368,672,372,1,8,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 13 l1_sc1,line 1 part 2,13,sc,1,692,366,150,926,1076,692,366,1,13,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 14 l1_sc1,line 1 part 2,1,sc,1,679,376,267,1185,1452,589,406,1,1,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 15 l1_sc1,line 1 part 2,1,sc,1,682,383,275,5248,5523,592,413,1,1,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 16 l1_sc1,line 1 part 2,10,sc,1,702,364,351,1610,1961,702,419,1,10,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 17 l1_sc1,line 1 part 2,13,sc,1,692,366,150,926,1076,692,366,1,13,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 18 l1_sc1,line 1 part 2,1,sc,1,662,390,309,6266,6575,572,420,1,1,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 19 l1_sc1,line 1 part 2,12,sc,1,673,379,300,643,943,673,389,1,12,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 20 l1_sc1,line 1 part 2,6,sc,1,708,402,100,1705,1805,708,417,1,6,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 21 l1_sc1,line 1 part 2,10,sc,1,672,388,350,526,876,672,443,1,10,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 22 l1_sc1,line 1 part 2,7,sc,1,705,372,342,2328,2670,750,367,1,7,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 23 l1_sc1,line 1 part 2,10,sc,1,698,388,175,1018,1193,698,443,1,10,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 24 l1_sc1,line 1 part 2,13,sc,1,660,391,242,642,884,660,391,1,13,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 25 l1_sc1,line 1 part 2,12,sc,1,678,391,142,29144,29286,678,401,1,12,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 26 l1_sc1,line 1 part 2,11,sc,1,699,395,292,409,701,699,510,1,11,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 27 l1_sc1,line 1 part 2,12,sc,1,654,369,108,11189,11297,654,379,1,12,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 28 l1_sc1,line 1 part 2,5,sc,1,668,389,200,409,609,668,389,1,5,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 29 l1_sc1,line 1 part 2,2,sc,1,661,388,308,459,767,661,423,1,2,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 30 l1_sc1,line 1 part 2,12,sc,1,664,395,150,1285,1435,664,405,1,12,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 31 l1_sc1,line 1 part 2,10,sc,1,687,373,267,2603,2870,687,428,1,10,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 32 l1_sc1,line 1 part 2,2,sc,1,661,388,308,459,767,661,423,1,2,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 33 l1_sc1,line 1 part 2,6,sc,1,687,407,100,25,125,687,422,1,6,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 34 l1_sc1,line 1 part 2,1,sc,1,699,391,192,6066,6258,609,421,1,1,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 35 l1_sc1,line 1 part 2,1,sc,1,698,393,234,6583,6817,608,423,1,1,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 36 l1_sc1,line 1 part 2,12,sc,1,666,373,250,28886,29136,666,383,1,12,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 37 l1_sc1,line 1 part 2,11,sc,1,704,400,242,18651,18893,704,515,1,11,sc1,0,line 1,0,sub-line,line 1 part 2,652,357,57,50,,class,class,5,2563.627936,0.01059009
# 38 l1_sc1,line 1 part 3,4,sc,1,552,368,292,13783,14075,552,368,1,4,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 39 l1_sc1,line 1 part 3,4,sc,1,526,380,267,13283,13550,526,380,1,4,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 40 l1_sc1,line 1 part 3,12,sc,1,721,367,175,1569,1744,721,377,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 41 l1_sc1,line 1 part 3,11,sc,1,794,387,208,4543,4751,794,502,1,11,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 42 l1_sc1,line 1 part 3,1,sc,1,758,399,217,1994,2211,668,429,1,1,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 43 l1_sc1,line 1 part 3,4,sc,1,630,374,242,2002,2244,630,374,1,4,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 44 l1_sc1,line 1 part 3,12,sc,1,799,386,276,29553,29829,799,396,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 45 l1_sc1,line 1 part 3,12,sc,1,833,385,317,29837,30154,833,395,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 46 l1_sc1,line 1 part 3,13,sc,1,759,384,192,1159,1351,759,384,1,13,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 47 l1_sc1,line 1 part 3,11,sc,1,767,394,342,3917,4259,767,509,1,11,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 48 l1_sc1,line 1 part 3,13,sc,1,759,384,192,1159,1351,759,384,1,13,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 49 l1_sc1,line 1 part 3,12,sc,1,735,372,309,951,1260,735,382,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 50 l1_sc1,line 1 part 3,10,sc,1,817,389,351,3345,3696,817,444,1,10,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 51 l1_sc1,line 1 part 3,1,sc,1,741,387,209,1460,1669,651,417,1,1,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 52 l1_sc1,line 1 part 3,11,sc,1,741,390,267,4267,4534,741,505,1,11,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 53 l1_sc1,line 1 part 3,13,sc,1,824,399,192,1368,1560,824,399,1,13,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 54 l1_sc1,line 1 part 3,13,sc,1,824,399,192,1368,1560,824,399,1,13,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 55 l1_sc1,line 1 part 3,11,sc,1,749,373,141,2520,2661,749,488,1,11,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 56 l1_sc1,line 1 part 3,7,sc,1,747,376,142,2687,2829,792,371,1,7,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 57 l1_sc1,line 1 part 3,12,sc,1,780,387,316,11640,11956,780,397,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 58 l1_sc1,line 1 part 3,4,sc,1,618,367,250,14292,14542,618,367,1,4,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 59 l1_sc1,line 1 part 3,2,sc,1,764,405,159,275,434,764,440,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 60 l1_sc1,line 1 part 3,12,sc,1,820,379,200,12040,12240,820,389,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 61 l1_sc1,line 1 part 3,12,sc,1,738,386,150,28719,28869,738,396,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 62 l1_sc1,line 1 part 3,4,sc,1,604,364,209,13566,13775,604,364,1,4,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 63 l1_sc1,line 1 part 3,2,sc,1,832,393,184,1251,1435,832,428,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 64 l1_sc1,line 1 part 3,2,sc,1,773,402,167,1452,1619,773,437,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 65 l1_sc1,line 1 part 3,2,sc,1,779,390,234,1009,1243,779,425,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 66 l1_sc1,line 1 part 3,10,sc,1,764,371,209,2002,2211,764,426,1,10,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 67 l1_sc1,line 1 part 3,11,sc,1,721,398,292,1835,2127,721,513,1,11,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 68 l1_sc1,line 1 part 3,4,sc,1,580,366,200,14084,14284,580,366,1,4,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 69 l1_sc1,line 1 part 3,10,sc,1,794,383,175,2219,2394,794,438,1,10,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 70 l1_sc1,line 1 part 3,5,sc,1,796,385,267,818,1085,796,385,1,5,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 71 l1_sc1,line 1 part 3,12,sc,1,842,400,200,1986,2186,842,410,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 72 l1_sc1,line 1 part 3,7,sc,1,717,362,183,234,417,762,357,1,7,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 73 l1_sc1,line 1 part 3,5,sc,1,721,380,184,617,801,721,380,1,5,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 74 l1_sc1,line 1 part 3,2,sc,1,773,402,167,1452,1619,773,437,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 75 l1_sc1,line 1 part 3,8,sc,1,730,372,242,2144,2386,730,362,1,8,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 76 l1_sc1,line 1 part 3,2,sc,1,779,390,234,1009,1243,779,425,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 77 l1_sc1,line 1 part 3,6,sc,1,738,399,100,7898,7998,738,414,1,6,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 78 l1_sc1,line 1 part 3,2,sc,1,717,382,200,793,993,717,417,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 79 l1_sc1,line 1 part 3,10,sc,1,756,380,209,3128,3337,756,435,1,10,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 80 l1_sc1,line 1 part 3,12,sc,1,795,388,226,1752,1978,795,398,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 81 l1_sc1,line 1 part 3,12,sc,1,731,383,250,29295,29545,731,393,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 82 l1_sc1,line 1 part 3,6,sc,1,821,382,192,2381,2573,821,397,1,6,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 83 l1_sc1,line 1 part 3,1,sc,1,808,393,184,7142,7326,718,423,1,1,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 84 l1_sc1,line 1 part 3,1,sc,1,729,395,267,5540,5807,639,425,1,1,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 85 l1_sc1,line 1 part 3,1,sc,1,791,400,216,5841,6057,701,430,1,1,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 86 l1_sc1,line 1 part 3,2,sc,1,832,393,184,1251,1435,832,428,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 87 l1_sc1,line 1 part 3,2,sc,1,717,382,200,793,993,717,417,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 88 l1_sc1,line 1 part 3,2,sc,1,764,405,159,275,434,764,440,1,2,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 89 l1_sc1,line 1 part 3,1,sc,1,766,382,309,6825,7134,676,412,1,1,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 90 l1_sc1,line 1 part 3,11,sc,1,843,366,100,3800,3900,843,481,1,11,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 91 l1_sc1,line 1 part 3,7,sc,1,755,378,193,2127,2320,800,373,1,7,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 92 l1_sc1,line 1 part 3,1,sc,1,779,392,292,1685,1977,689,422,1,1,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 93 l1_sc1,line 1 part 3,1,sc,1,791,394,242,2219,2461,701,424,1,1,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 94 l1_sc1,line 1 part 3,11,sc,1,836,381,209,4759,4968,836,496,1,11,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 95 l1_sc1,line 1 part 3,10,sc,1,731,398,133,3704,3837,731,453,1,10,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 96 l1_sc1,line 1 part 3,7,sc,1,807,381,183,1936,2119,852,376,1,7,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 97 l1_sc1,line 1 part 3,6,sc,1,761,392,234,2122,2356,761,407,1,6,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 98 l1_sc1,line 1 part 3,7,sc,1,732,373,150,1285,1435,777,368,1,7,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 99 l1_sc1,line 1 part 3,12,sc,1,781,374,158,31239,31397,781,384,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 100 l1_sc1,line 1 part 3,12,sc,1,715,375,308,11306,11614,715,385,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 101 l1_sc1,line 1 part 3,12,sc,1,756,378,192,31038,31230,756,388,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 102 l1_sc1,line 1 part 3,11,sc,1,807,395,276,1468,1744,807,510,1,11,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 103 l1_sc1,line 1 part 3,12,sc,1,717,393,300,30730,31030,717,403,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 104 l1_sc1,line 1 part 3,12,sc,1,839,373,125,31447,31572,839,383,1,12,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 105 l1_sc1,line 1 part 3,4,sc,1,532,387,359,1159,1518,532,387,1,4,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 106 l1_sc1,line 1 part 3,5,sc,1,742,382,150,250,400,742,382,1,5,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 107 l1_sc1,line 1 part 3,6,sc,1,788,361,209,1863,2072,788,376,1,6,sc1,0,line 1,0,sub-line,line 1 part 3,715,357,134,50,,PrinterClass,PrinterClass,12,0,9.96E-07
# 108 l1_sc1,line 2 part 1,6,sc,1,693,450,276,2589,2865,693,465,1,6,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 109 l1_sc1,line 2 part 1,13,sc,1,699,436,134,500,634,699,436,1,13,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 110 l1_sc1,line 2 part 1,7,sc,1,695,440,275,2837,3112,740,435,1,7,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 111 l1_sc1,line 2 part 1,13,sc,1,693,432,175,1585,1760,693,432,1,13,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 112 l1_sc1,line 2 part 1,9,sc,1,668,416,242,1427,1669,668,441,1,9,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 113 l1_sc1,line 2 part 1,13,sc,1,699,436,134,500,634,699,436,1,13,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 114 l1_sc1,line 2 part 1,5,sc,1,701,429,209,1101,1310,701,429,1,5,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 115 l1_sc1,line 2 part 1,8,sc,1,660,436,234,2703,2937,660,436,1,8,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 116 l1_sc1,line 2 part 1,4,sc,1,456,419,233,12482,12715,456,419,1,4,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 117 l1_sc1,line 2 part 1,9,sc,1,684,426,133,434,567,684,451,1,9,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 118 l1_sc1,line 2 part 1,4,sc,1,454,419,275,2261,2536,454,419,1,4,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 119 l1_sc1,line 2 part 1,13,sc,1,693,432,175,1585,1760,693,432,1,13,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 120 l1_sc1,line 2 part 1,10,sc,1,699,431,342,3846,4188,699,486,1,10,sc1,0,line 2,0,sub-line,line 2 part 1,636,413,65,50,,public,public,6,19831.13901,0.042731726
# 121 l1_sc1,line 2 part 11,8,sc,1,1067,439,276,4221,4497,1067,439,1,8,sc1,0,line 2,0,sub-line,line 2 part 11,1063,413,10,50,,},},1,43801.58225,1.01E-06
# 122 l1_sc1,line 2 part 2,1,sc,1,758,430,334,3045,3379,668,460,1,1,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 123 l1_sc1,line 2 part 2,1,sc,1,752,437,209,4856,5065,662,467,1,1,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 124 l1_sc1,line 2 part 2,4,sc,1,528,414,376,15118,15494,528,414,1,4,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 125 l1_sc1,line 2 part 2,11,sc,1,741,428,284,5460,5744,741,543,1,11,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 126 l1_sc1,line 2 part 2,11,sc,1,742,428,275,6028,6303,742,543,1,11,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 127 l1_sc1,line 2 part 2,6,sc,1,764,460,150,7706,7856,764,475,1,6,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 128 l1_sc1,line 2 part 2,10,sc,1,710,416,117,401,518,710,471,1,10,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 129 l1_sc1,line 2 part 2,10,sc,1,725,421,117,4288,4405,725,476,1,10,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 130 l1_sc1,line 2 part 2,12,sc,1,754,429,108,10580,10688,754,439,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 131 l1_sc1,line 2 part 2,2,sc,1,731,429,100,1911,2011,731,464,1,2,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 132 l1_sc1,line 2 part 2,12,sc,1,758,441,200,234,434,758,451,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 133 l1_sc1,line 2 part 2,12,sc,1,712,427,183,28085,28268,712,437,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 134 l1_sc1,line 2 part 2,1,sc,1,725,421,184,976,1160,635,451,1,1,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 135 l1_sc1,line 2 part 2,1,sc,1,716,427,167,5073,5240,626,457,1,1,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 136 l1_sc1,line 2 part 2,11,sc,1,729,427,350,18293,18643,729,542,1,11,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 137 l1_sc1,line 2 part 2,2,sc,1,708,422,275,1627,1902,708,457,1,2,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 138 l1_sc1,line 2 part 2,11,sc,1,734,450,242,4985,5227,734,550,1,11,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 139 l1_sc1,line 2 part 2,12,sc,1,743,443,142,9679,9821,743,453,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 140 l1_sc1,line 2 part 2,13,sc,1,760,447,150,1785,1935,760,447,1,13,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 141 l1_sc1,line 2 part 2,7,sc,1,758,431,166,3246,3412,803,426,1,7,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 142 l1_sc1,line 2 part 2,13,sc,1,760,447,150,1785,1935,760,447,1,13,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 143 l1_sc1,line 2 part 2,10,sc,1,740,433,167,10310,10477,740,488,1,10,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 144 l1_sc1,line 2 part 2,5,sc,1,735,443,234,1318,1552,735,443,1,5,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 145 l1_sc1,line 2 part 2,12,sc,1,736,453,292,25949,26241,736,463,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 146 l1_sc1,line 2 part 2,13,sc,1,733,431,225,267,492,733,431,1,13,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 147 l1_sc1,line 2 part 2,8,sc,1,757,437,217,2978,3195,757,437,1,8,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 148 l1_sc1,line 2 part 2,12,sc,1,761,446,217,23262,23479,761,456,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 149 l1_sc1,line 2 part 2,2,sc,1,708,422,275,1627,1902,708,457,1,2,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 150 l1_sc1,line 2 part 2,11,sc,1,743,428,209,19886,20095,743,543,1,11,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 151 l1_sc1,line 2 part 2,7,sc,1,715,430,117,3120,3237,760,425,1,7,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 152 l1_sc1,line 2 part 2,12,sc,1,710,423,192,442,634,710,433,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 153 l1_sc1,line 2 part 2,13,sc,1,711,462,142,11814,11956,711,462,1,13,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 154 l1_sc1,line 2 part 2,4,sc,1,561,417,234,15502,15736,561,417,1,4,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 155 l1_sc1,line 2 part 2,12,sc,1,713,438,367,31714,32081,713,448,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 156 l1_sc1,line 2 part 2,12,sc,1,761,446,308,32090,32398,761,456,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 157 l1_sc1,line 2 part 2,12,sc,1,720,457,192,25306,25498,720,467,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 158 l1_sc1,line 2 part 2,12,sc,1,734,446,342,2203,2545,734,456,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 159 l1_sc1,line 2 part 2,2,sc,1,731,429,100,1911,2011,731,464,1,2,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 160 l1_sc1,line 2 part 2,13,sc,1,753,433,317,11113,11430,753,433,1,13,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 161 l1_sc1,line 2 part 2,13,sc,1,711,462,142,11814,11956,711,462,1,13,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 162 l1_sc1,line 2 part 2,4,sc,1,510,436,259,2544,2803,510,436,1,4,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 163 l1_sc1,line 2 part 2,12,sc,1,739,442,142,23487,23629,739,452,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 164 l1_sc1,line 2 part 2,12,sc,1,734,441,292,27784,28076,734,451,1,12,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 165 l1_sc1,line 2 part 2,13,sc,1,733,431,225,267,492,733,431,1,13,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 166 l1_sc1,line 2 part 2,4,sc,1,534,428,308,2987,3295,534,428,1,4,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 167 l1_sc1,line 2 part 2,10,sc,1,718,432,134,10485,10619,718,487,1,10,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 168 l1_sc1,line 2 part 2,13,sc,1,753,433,317,11113,11430,753,433,1,13,sc1,0,line 2,0,sub-line,line 2 part 2,706,413,59,50,,static,static,6,6969.496395,0.026724609
# 169 l1_sc1,line 2 part 3,4,sc,1,611,416,250,15744,15994,611,416,1,4,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 170 l1_sc1,line 2 part 3,13,sc,1,815,455,208,1944,2152,815,455,1,13,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 171 l1_sc1,line 2 part 3,10,sc,1,812,439,342,4738,5080,812,494,1,10,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 172 l1_sc1,line 2 part 3,11,sc,1,783,427,192,6311,6503,783,542,1,11,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 173 l1_sc1,line 2 part 3,12,sc,1,791,436,334,10238,10572,791,446,1,12,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 174 l1_sc1,line 2 part 3,13,sc,1,815,455,208,1944,2152,815,455,1,13,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 175 l1_sc1,line 2 part 3,11,sc,1,779,424,259,5752,6011,779,539,1,11,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 176 l1_sc1,line 2 part 3,11,sc,1,813,423,242,18042,18284,813,538,1,11,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 177 l1_sc1,line 2 part 3,1,sc,1,786,427,133,13959,14092,696,457,1,1,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 178 l1_sc1,line 2 part 3,12,sc,1,792,438,208,23638,23846,792,448,1,12,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 179 l1_sc1,line 2 part 3,10,sc,1,774,437,317,4413,4730,774,492,1,10,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 180 l1_sc1,line 2 part 3,4,sc,1,571,438,242,3304,3546,571,438,1,4,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 181 l1_sc1,line 2 part 3,12,sc,1,792,437,183,32407,32590,792,447,1,12,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 182 l1_sc1,line 2 part 3,11,sc,1,784,429,217,5235,5452,784,544,1,11,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 183 l1_sc1,line 2 part 3,10,sc,1,795,456,167,10627,10794,795,511,1,10,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 184 l1_sc1,line 2 part 3,4,sc,1,574,437,158,2820,2978,574,437,1,4,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 185 l1_sc1,line 2 part 3,12,sc,1,800,450,350,25590,25940,800,460,1,12,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 186 l1_sc1,line 2 part 3,5,sc,1,804,433,167,1560,1727,804,433,1,5,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 187 l1_sc1,line 2 part 3,7,sc,1,806,435,267,3421,3688,851,430,1,7,sc1,0,line 2,0,sub-line,line 2 part 3,770,413,45,50,,void,void,4,8263.164912,0.003355203
# 188 l1_sc1,line 2 part 4,2,sc,1,827,444,217,2027,2244,827,479,1,2,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 189 l1_sc1,line 2 part 4,11,sc,1,848,425,158,6812,6970,848,540,1,11,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 190 l1_sc1,line 2 part 4,11,sc,1,823,426,192,19686,19878,823,541,1,11,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 191 l1_sc1,line 2 part 4,2,sc,1,840,443,259,0,259,840,478,1,2,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 192 l1_sc1,line 2 part 4,4,sc,1,642,447,284,17780,18064,642,447,1,4,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 193 l1_sc1,line 2 part 4,12,sc,1,857,447,284,24847,25131,857,457,1,12,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 194 l1_sc1,line 2 part 4,7,sc,1,843,429,200,3696,3896,888,424,1,7,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 195 l1_sc1,line 2 part 4,1,sc,1,829,440,259,8811,9070,739,470,1,1,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 196 l1_sc1,line 2 part 4,2,sc,1,840,443,259,0,259,840,478,1,2,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 197 l1_sc1,line 2 part 4,1,sc,1,860,449,317,10872,11189,770,479,1,1,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 198 l1_sc1,line 2 part 4,2,sc,1,827,444,217,2027,2244,827,479,1,2,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 199 l1_sc1,line 2 part 4,1,sc,1,829,430,192,15119,15311,739,460,1,1,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 200 l1_sc1,line 2 part 4,8,sc,1,848,435,300,3212,3512,848,455,1,8,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 201 l1_sc1,line 2 part 4,13,sc,1,845,448,183,2161,2344,845,448,1,13,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 202 l1_sc1,line 2 part 4,13,sc,1,845,448,183,2161,2344,845,448,1,13,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 203 l1_sc1,line 2 part 4,12,sc,1,825,437,217,32599,32816,825,447,1,12,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 204 l1_sc1,line 2 part 4,10,sc,1,844,448,208,5089,5297,844,503,1,10,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 205 l1_sc1,line 2 part 4,4,sc,1,641,430,266,4105,4371,641,430,1,4,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 206 l1_sc1,line 2 part 4,12,sc,1,822,462,151,25139,25290,822,472,1,12,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 207 l1_sc1,line 2 part 4,10,sc,1,828,443,217,10802,11019,828,498,1,10,sc1,0,line 2,0,sub-line,line 2 part 4,822,413,53,50,,main,main,4,9.788160285,1.51E-05
# 208 l1_sc1,line 2 part 5,8,sc,1,890,446,133,0,133,890,466,1,8,sc1,0,line 2,0,sub-line,line 2 part 5,882,413,9,50,,(,(,1,1602.756868,1.01E-06
# 209 l1_sc1,line 2 part 5,1,sc,1,885,424,275,3788,4063,795,454,1,1,sc1,0,line 2,0,sub-line,line 2 part 5,882,413,9,50,,(,(,1,1602.756868,1.01E-06
# 210 l1_sc1,line 2 part 5,1,sc,1,882,445,159,14543,14702,792,475,1,1,sc1,0,line 2,0,sub-line,line 2 part 5,882,413,9,50,,(,(,1,1602.756868,1.01E-06
# 211 l1_sc1,line 2 part 6,11,sc,1,931,416,284,7696,7980,931,531,1,11,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 212 l1_sc1,line 2 part 6,11,sc,1,951,428,317,7988,8305,951,543,1,11,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 213 l1_sc1,line 2 part 6,1,sc,1,899,443,125,15319,15444,809,473,1,1,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 214 l1_sc1,line 2 part 6,1,sc,1,906,441,342,11356,11698,816,471,1,1,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 215 l1_sc1,line 2 part 6,11,sc,1,917,450,243,9982,10225,917,550,1,11,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 216 l1_sc1,line 2 part 6,1,sc,1,900,441,117,10513,10630,810,471,1,1,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 217 l1_sc1,line 2 part 6,12,sc,1,918,443,167,9095,9262,918,453,1,12,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 218 l1_sc1,line 2 part 6,5,sc,1,919,437,267,1752,2019,919,437,1,5,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 219 l1_sc1,line 2 part 6,6,sc,1,925,442,208,8207,8415,925,457,1,6,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 220 l1_sc1,line 2 part 6,4,sc,1,723,450,175,16111,16286,723,450,1,4,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 221 l1_sc1,line 2 part 6,4,sc,1,719,420,367,4380,4747,719,420,1,4,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 222 l1_sc1,line 2 part 6,11,sc,1,928,424,150,7413,7563,928,539,1,11,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 223 l1_sc1,line 2 part 6,10,sc,1,916,446,283,11036,11319,916,501,1,10,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 224 l1_sc1,line 2 part 6,2,sc,1,943,444,209,2261,2470,943,479,1,2,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 225 l1_sc1,line 2 part 6,6,sc,1,901,431,275,4302,4577,901,446,1,6,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 226 l1_sc1,line 2 part 6,1,sc,1,907,440,100,12541,12641,817,470,1,1,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 227 l1_sc1,line 2 part 6,4,sc,1,737,432,251,16603,16854,737,432,1,4,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 228 l1_sc1,line 2 part 6,11,sc,1,898,428,242,19169,19411,898,543,1,11,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 229 l1_sc1,line 2 part 6,8,sc,1,905,436,108,3671,3779,905,456,1,8,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 230 l1_sc1,line 2 part 6,7,sc,1,940,427,376,3913,4289,985,422,1,7,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 231 l1_sc1,line 2 part 6,4,sc,1,703,427,200,3888,4088,703,427,1,4,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 232 l1_sc1,line 2 part 6,6,sc,1,961,438,175,8023,8198,961,453,1,6,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 233 l1_sc1,line 2 part 6,4,sc,1,735,428,259,18072,18331,735,428,1,4,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 234 l1_sc1,line 2 part 6,11,sc,1,932,426,242,19419,19661,932,541,1,11,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 235 l1_sc1,line 2 part 6,11,sc,1,931,434,258,10425,10683,931,549,1,11,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 236 l1_sc1,line 2 part 6,2,sc,1,943,444,209,2261,2470,943,479,1,2,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 237 l1_sc1,line 2 part 6,13,sc,1,930,442,259,2361,2620,930,442,1,13,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 238 l1_sc1,line 2 part 6,12,sc,1,928,460,250,4222,4472,928,470,1,12,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 239 l1_sc1,line 2 part 6,12,sc,1,939,441,350,21585,21935,939,451,1,12,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 240 l1_sc1,line 2 part 6,10,sc,1,960,441,226,5622,5848,960,496,1,10,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 241 l1_sc1,line 2 part 6,13,sc,1,930,442,259,2361,2620,930,442,1,13,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 242 l1_sc1,line 2 part 6,10,sc,1,925,440,167,5856,6023,925,495,1,10,sc1,0,line 2,0,sub-line,line 2 part 6,897,413,64,50,,String,String,6,8639.356539,1.01E-06
# 243 l1_sc1,line 2 part 7,1,sc,1,974,420,300,4080,4380,884,450,1,1,sc1,0,line 2,0,sub-line,line 2 part 7,968,413,8,50,,[,[,1,17.61868851,1.01E-06
# 244 l1_sc1,line 2 part 7,12,sc,1,973,442,201,32832,33033,973,452,1,12,sc1,0,line 2,0,sub-line,line 2 part 7,968,413,8,50,,[,[,1,17.61868851,1.01E-06
# 245 l1_sc1,line 2 part 7,10,sc,1,974,439,109,6039,6148,974,494,1,10,sc1,0,line 2,0,sub-line,line 2 part 7,968,413,8,50,,[,[,1,17.61868851,1.01E-06
# 246 l1_sc1,line 2 part 7,5,sc,1,970,438,258,2028,2286,970,438,1,5,sc1,0,line 2,0,sub-line,line 2 part 7,968,413,8,50,,[,[,1,17.61868851,1.01E-06
# 247 l1_sc1,line 2 part 8,10,sc,1,987,438,142,11561,11703,987,493,1,10,sc1,0,line 2,0,sub-line,line 2 part 8,980,413,8,50,,],],1,52.31227886,1.01E-06
# 248 l1_sc1,line 2 part 8,8,sc,1,983,440,125,3980,4105,983,460,1,8,sc1,0,line 2,0,sub-line,line 2 part 8,980,413,8,50,,],],1,52.31227886,1.01E-06
# 249 l1_sc1,line 2 part 9,12,sc,1,1030,458,368,33249,33617,1030,468,1,12,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 250 l1_sc1,line 2 part 9,12,sc,1,1018,438,225,33625,33850,1018,448,1,12,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 251 l1_sc1,line 2 part 9,4,sc,1,818,432,125,5189,5314,818,432,1,4,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 252 l1_sc1,line 2 part 9,1,sc,1,997,428,317,4506,4823,907,458,1,1,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 253 l1_sc1,line 2 part 9,4,sc,1,815,416,200,17555,17755,815,416,1,4,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 254 l1_sc1,line 2 part 9,9,sc,1,1024,437,342,13834,14176,1024,462,1,9,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 255 l1_sc1,line 2 part 9,12,sc,1,1002,436,100,9554,9654,1002,446,1,12,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 256 l1_sc1,line 2 part 9,11,sc,1,1026,427,292,10692,10984,1026,542,1,11,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 257 l1_sc1,line 2 part 9,12,sc,1,1006,446,200,33041,33241,1006,456,1,12,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 258 l1_sc1,line 2 part 9,8,sc,1,1035,432,117,3821,3938,1035,452,1,8,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 259 l1_sc1,line 2 part 9,13,sc,1,1017,444,117,2853,2970,1017,444,1,13,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 260 l1_sc1,line 2 part 9,4,sc,1,829,412,217,5323,5540,829,412,1,4,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 261 l1_sc1,line 2 part 9,13,sc,1,1017,444,117,2853,2970,1017,444,1,13,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 262 l1_sc1,line 2 part 9,12,sc,1,1003,451,283,4848,5131,1003,461,1,12,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 263 l1_sc1,line 2 part 9,9,sc,1,1011,454,234,14184,14418,1011,479,1,9,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 264 l1_sc1,line 2 part 9,1,sc,1,1009,432,383,16963,17346,919,462,1,1,sc1,0,line 2,0,sub-line,line 2 part 9,994,413,49,50,,args,args,4,63.29676984,1.01E-06
# 265 l1_sc1,line 3 part 2,12,sc,1,878,484,209,34025,34234,878,494,1,12,sc1,0,line 3,0,sub-line,line 3 part 2,874,469,8,50,,(,(,1,1602.756868,1.01E-06
# 266 l1_sc1,line 3 part 2,1,sc,1,879,485,150,9170,9320,789,485,1,1,sc1,0,line 3,0,sub-line,line 3 part 2,874,469,8,50,,(,(,1,1602.756868,1.01E-06
# 267 l1_sc1,line 3 part 2,12,sc,1,876,497,208,14318,14526,876,507,1,12,sc1,0,line 3,0,sub-line,line 3 part 2,874,469,8,50,,(,(,1,1602.756868,1.01E-06
# 268 l1_sc1,line 3 part 3,1,sc,1,918,495,301,10204,10505,828,495,1,1,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 269 l1_sc1,line 3 part 3,11,sc,1,936,503,267,34821,35088,936,603,1,11,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 270 l1_sc1,line 3 part 3,7,sc,1,957,514,100,10680,10780,1002,514,1,7,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 271 l1_sc1,line 3 part 3,8,sc,1,997,489,167,5715,5882,1037,509,1,8,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 272 l1_sc1,line 3 part 3,13,sc,1,976,482,325,8093,8418,976,482,1,13,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 273 l1_sc1,line 3 part 3,13,sc,1,918,497,142,6875,7017,918,497,1,13,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 274 l1_sc1,line 3 part 3,2,sc,1,938,485,167,5573,5740,938,520,1,2,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 275 l1_sc1,line 3 part 3,2,sc,1,930,485,317,3396,3713,930,520,1,2,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 276 l1_sc1,line 3 part 3,11,sc,1,947,514,293,42455,42748,947,614,1,11,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 277 l1_sc1,line 3 part 3,7,sc,1,944,480,275,13809,14084,989,480,1,7,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 278 l1_sc1,line 3 part 3,7,sc,1,929,481,276,8919,9195,974,481,1,7,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 279 l1_sc1,line 3 part 3,5,sc,1,926,476,167,5715,5882,926,476,1,5,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 280 l1_sc1,line 3 part 3,1,sc,1,913,498,259,14276,14535,823,498,1,1,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 281 l1_sc1,line 3 part 3,11,sc,1,922,508,250,16107,16357,922,608,1,11,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 282 l1_sc1,line 3 part 3,12,sc,1,944,493,383,14677,15060,944,503,1,12,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 283 l1_sc1,line 3 part 3,7,sc,1,980,474,125,17046,17171,1025,474,1,7,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 284 l1_sc1,line 3 part 3,9,sc,1,935,492,209,10012,10221,935,517,1,9,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 285 l1_sc1,line 3 part 3,2,sc,1,952,510,167,5857,6024,952,545,1,2,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 286 l1_sc1,line 3 part 3,11,sc,1,916,482,176,17408,17584,916,582,1,11,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 287 l1_sc1,line 3 part 3,2,sc,1,930,485,317,3396,3713,930,520,1,2,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 288 l1_sc1,line 3 part 3,10,sc,1,923,508,325,13105,13430,923,563,1,10,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 289 l1_sc1,line 3 part 3,7,sc,1,970,516,242,15836,16078,1015,516,1,7,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 290 l1_sc1,line 3 part 3,2,sc,1,962,477,100,5749,5849,962,512,1,2,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 291 l1_sc1,line 3 part 3,11,sc,1,922,498,292,16649,16941,922,598,1,11,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 292 l1_sc1,line 3 part 3,7,sc,1,970,475,117,14092,14209,1015,475,1,7,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 293 l1_sc1,line 3 part 3,11,sc,1,927,487,233,21038,21271,927,587,1,11,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 294 l1_sc1,line 3 part 3,1,sc,1,916,508,334,18823,19157,826,508,1,1,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 295 l1_sc1,line 3 part 3,10,sc,1,888,483,100,6790,6890,888,538,1,10,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 296 l1_sc1,line 3 part 3,2,sc,1,952,510,167,5857,6024,952,545,1,2,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 297 l1_sc1,line 3 part 3,13,sc,1,934,511,267,9395,9662,934,511,1,13,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 298 l1_sc1,line 3 part 3,2,sc,1,962,477,100,5749,5849,962,512,1,2,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 299 l1_sc1,line 3 part 3,12,sc,1,923,507,150,40634,40784,923,517,1,12,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 300 l1_sc1,line 3 part 3,12,sc,1,912,498,275,39891,40166,912,508,1,12,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 301 l1_sc1,line 3 part 3,4,sc,1,731,501,209,23737,23946,731,501,1,4,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# 302 l1_sc1,line 3 part 3,13,sc,1,906,506,250,9670,9920,906,506,1,13,sc1,0,line 3,0,sub-line,line 3 part 3,888,469,111,50,,"""answer=""","""answer=""",13,0,1.01E-06
# ...
# 8889 l6_sc3,line 3 part 8,3,sc,3,833,385,141,45632,45773,833,385,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8890 l6_sc3,line 3 part 8,3,sc,3,819,392,225,45031,45256,819,412,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8891 l6_sc3,line 3 part 8,3,sc,3,828,371,108,12366,12474,828,371,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8892 l6_sc3,line 3 part 8,3,sc,3,813,379,309,38439,38748,813,379,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8893 l6_sc3,line 3 part 8,3,sc,3,828,388,175,19800,19975,828,408,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8894 l6_sc3,line 3 part 8,3,sc,3,846,394,109,57479,57588,846,394,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8895 l6_sc3,line 3 part 8,3,sc,3,826,391,158,58022,58180,826,391,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8896 l6_sc3,line 3 part 8,3,sc,3,818,381,275,7468,7743,818,401,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8897 l6_sc3,line 3 part 8,3,sc,3,835,365,334,46232,46566,835,365,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8898 l6_sc3,line 3 part 8,4,sc,3,821,375,217,4313,4530,821,405,3,4,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8899 l6_sc3,line 3 part 8,5,sc,3,824,373,125,4289,4414,824,373,3,5,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8900 l6_sc3,line 3 part 8,5,sc,3,825,380,375,50880,51255,825,380,3,5,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8901 l6_sc3,line 3 part 8,3,sc,3,842,385,242,67083,67325,842,405,3,3,sc3,none,line 3,0,sub-line,line 3 part 8,812,364,36,30,,row,row,3,66.88576195,1.01E-06
# 8902 l6_sc3,line 3 part 9,3,sc,3,854,370,167,57304,57471,854,370,3,3,sc3,none,line 3,0,sub-line,line 3 part 9,853,364,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8903 l6_sc3,line 3 part 9,4,sc,3,875,382,267,18789,19056,875,412,3,4,sc3,none,line 3,0,sub-line,line 3 part 9,853,364,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8904 l6_sc3,line 3 part 9,3,sc,3,871,387,309,61259,61568,871,387,3,3,sc3,none,line 3,0,sub-line,line 3 part 9,853,364,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8905 l6_sc3,line 3 part 9,3,sc,3,857,369,167,38965,39132,857,369,3,3,sc3,none,line 3,0,sub-line,line 3 part 9,853,364,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8906 l6_sc3,line 3 part 9,3,sc,3,868,387,150,1744,1894,868,387,3,3,sc3,none,line 3,0,sub-line,line 3 part 9,853,364,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8907 l6_sc3,line 3 part 9,3,sc,3,866,390,233,75477,75710,866,410,3,3,sc3,none,line 3,0,sub-line,line 3 part 9,853,364,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8908 l6_sc3,line 4 part 1,5,sc,3,731,421,300,54743,55043,731,421,3,5,sc3,none,line 4,0,sub-line,line 4 part 1,704,401,28,30,,for,for,3,3559.192594,0.006413993
# 8909 l6_sc3,line 4 part 1,5,sc,3,714,401,159,49661,49820,714,401,3,5,sc3,none,line 4,0,sub-line,line 4 part 1,704,401,28,30,,for,for,3,3559.192594,0.006413993
# 8910 l6_sc3,line 4 part 1,4,sc,3,717,411,376,32314,32690,717,441,3,4,sc3,none,line 4,0,sub-line,line 4 part 1,704,401,28,30,,for,for,3,3559.192594,0.006413993
# 8911 l6_sc3,line 4 part 10,3,sc,3,928,410,242,60408,60650,928,430,3,3,sc3,none,line 4,0,sub-line,line 4 part 10,923,401,36,30,,row,row,3,66.88576195,1.01E-06
# 8912 l6_sc3,line 4 part 10,4,sc,3,934,410,125,20325,20450,934,440,3,4,sc3,none,line 4,0,sub-line,line 4 part 10,923,401,36,30,,row,row,3,66.88576195,1.01E-06
# 8913 l6_sc3,line 4 part 10,3,sc,3,929,417,225,82911,83136,929,437,3,3,sc3,none,line 4,0,sub-line,line 4 part 10,923,401,36,30,,row,row,3,66.88576195,1.01E-06
# 8914 l6_sc3,line 4 part 10,5,sc,3,958,411,267,4873,5140,958,411,3,5,sc3,none,line 4,0,sub-line,line 4 part 10,923,401,36,30,,row,row,3,66.88576195,1.01E-06
# 8915 l6_sc3,line 4 part 10,5,sc,3,958,426,100,56078,56178,958,426,3,5,sc3,none,line 4,0,sub-line,line 4 part 10,923,401,36,30,,row,row,3,66.88576195,1.01E-06
# 8916 l6_sc3,line 4 part 10,5,sc,3,932,404,209,38848,39057,932,404,3,5,sc3,none,line 4,0,sub-line,line 4 part 10,923,401,36,30,,row,row,3,66.88576195,1.01E-06
# 8917 l6_sc3,line 4 part 10,3,sc,3,941,401,259,49853,50112,941,421,3,3,sc3,none,line 4,0,sub-line,line 4 part 10,923,401,36,30,,row,row,3,66.88576195,1.01E-06
# 8918 l6_sc3,line 4 part 12,3,sc,3,1000,426,158,43162,43320,1000,446,3,3,sc3,none,line 4,0,sub-line,line 4 part 12,975,401,28,30,,col,col,3,17.94496052,1.01E-06
# 8919 l6_sc3,line 4 part 12,3,sc,3,978,405,258,42670,42928,978,425,3,3,sc3,none,line 4,0,sub-line,line 4 part 12,975,401,28,30,,col,col,3,17.94496052,1.01E-06
# 8920 l6_sc3,line 4 part 12,4,sc,3,988,417,166,24188,24354,988,447,3,4,sc3,none,line 4,0,sub-line,line 4 part 12,975,401,28,30,,col,col,3,17.94496052,1.01E-06
# 8921 l6_sc3,line 4 part 12,5,sc,3,977,418,292,51580,51872,977,418,3,5,sc3,none,line 4,0,sub-line,line 4 part 12,975,401,28,30,,col,col,3,17.94496052,1.01E-06
# 8922 l6_sc3,line 4 part 12,5,sc,3,1001,408,192,39115,39307,1001,408,3,5,sc3,none,line 4,0,sub-line,line 4 part 12,975,401,28,30,,col,col,3,17.94496052,1.01E-06
# 8923 l6_sc3,line 4 part 13,5,sc,3,1025,408,183,51881,52064,1025,408,3,5,sc3,none,line 4,0,sub-line,line 4 part 13,1009,401,25,30,,++,++,2,8.37431491,1.01E-06
# 8924 l6_sc3,line 4 part 13,3,sc,3,1030,414,293,20834,21127,1030,434,3,3,sc3,none,line 4,0,sub-line,line 4 part 13,1009,401,25,30,,++,++,2,8.37431491,1.01E-06
# 8925 l6_sc3,line 4 part 2,3,sc,3,743,407,192,11890,12082,743,427,3,3,sc3,none,line 4,0,sub-line,line 4 part 2,736,401,8,30,,(,(,1,1602.756868,0.001516968
# 8926 l6_sc3,line 4 part 3,4,sc,3,769,427,167,32698,32865,769,457,3,4,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8927 l6_sc3,line 4 part 3,5,sc,3,773,423,183,9162,9345,773,423,3,5,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8928 l6_sc3,line 4 part 3,3,sc,3,767,409,325,32107,32432,767,429,3,3,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8929 l6_sc3,line 4 part 3,5,sc,3,751,428,133,54259,54392,751,428,3,5,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8930 l6_sc3,line 4 part 3,4,sc,3,749,417,100,16245,16345,749,447,3,4,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8931 l6_sc3,line 4 part 3,3,sc,3,766,413,259,14560,14819,766,433,3,3,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8932 l6_sc3,line 4 part 3,3,sc,3,767,413,325,82569,82894,767,433,3,3,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8933 l6_sc3,line 4 part 3,5,sc,3,756,425,108,26308,26416,756,425,3,5,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8934 l6_sc3,line 4 part 3,3,sc,3,749,408,225,15253,15478,749,428,3,3,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8935 l6_sc3,line 4 part 3,4,sc,3,771,426,350,14242,14592,771,456,3,4,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8936 l6_sc3,line 4 part 3,5,sc,3,763,431,334,57104,57438,763,431,3,5,sc3,none,line 4,0,sub-line,line 4 part 3,749,401,24,30,,int,int,3,7523.832539,0.000184324
# 8937 l6_sc3,line 4 part 4,3,sc,3,786,428,317,81818,82135,786,448,3,3,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8938 l6_sc3,line 4 part 4,3,sc,3,785,403,292,64880,65172,785,423,3,3,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8939 l6_sc3,line 4 part 4,4,sc,3,805,414,200,25531,25731,805,444,3,4,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8940 l6_sc3,line 4 part 4,5,sc,3,787,431,325,46024,46349,787,431,3,5,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8941 l6_sc3,line 4 part 4,3,sc,3,789,415,134,12090,12224,789,435,3,3,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8942 l6_sc3,line 4 part 4,5,sc,3,790,430,158,44597,44755,790,430,3,5,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8943 l6_sc3,line 4 part 4,4,sc,3,786,402,368,38905,39273,786,432,3,4,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8944 l6_sc3,line 4 part 4,4,sc,3,805,404,267,17179,17446,805,434,3,4,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8945 l6_sc3,line 4 part 4,4,sc,3,794,406,142,16361,16503,794,436,3,4,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8946 l6_sc3,line 4 part 4,3,sc,3,802,410,250,14827,15077,802,430,3,3,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8947 l6_sc3,line 4 part 4,4,sc,3,789,410,217,14017,14234,789,440,3,4,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8948 l6_sc3,line 4 part 4,3,sc,3,804,412,208,20601,20809,804,432,3,3,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8949 l6_sc3,line 4 part 4,5,sc,3,785,423,308,45148,45456,785,423,3,5,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8950 l6_sc3,line 4 part 4,3,sc,3,787,429,158,15086,15244,787,449,3,3,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8951 l6_sc3,line 4 part 4,4,sc,3,784,410,167,38096,38263,784,440,3,4,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8952 l6_sc3,line 4 part 4,3,sc,3,795,424,334,32966,33300,795,444,3,3,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8953 l6_sc3,line 4 part 4,4,sc,3,790,422,159,37487,37646,790,452,3,4,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8954 l6_sc3,line 4 part 4,3,sc,3,790,412,284,7176,7460,790,432,3,3,sc3,none,line 4,0,sub-line,line 4 part 4,777,401,29,30,,col,col,3,17.94496052,1.01E-06
# 8955 l6_sc3,line 4 part 5,3,sc,3,814,402,108,73216,73324,814,422,3,3,sc3,none,line 4,0,sub-line,line 4 part 5,811,401,13,30,,=,=,1,48102.60863,1.01E-05
# 8956 l6_sc3,line 4 part 5,3,sc,3,813,423,125,22470,22595,813,443,3,3,sc3,none,line 4,0,sub-line,line 4 part 5,811,401,13,30,,=,=,1,48102.60863,1.01E-05
# 8957 l6_sc3,line 4 part 5,5,sc,3,814,431,225,49194,49419,814,431,3,5,sc3,none,line 4,0,sub-line,line 4 part 5,811,401,13,30,,=,=,1,48102.60863,1.01E-05
# 8958 l6_sc3,line 4 part 5,5,sc,3,815,412,109,46357,46466,815,412,3,5,sc3,none,line 4,0,sub-line,line 4 part 5,811,401,13,30,,=,=,1,48102.60863,1.01E-05
# 8959 l6_sc3,line 4 part 5,3,sc,3,818,401,301,25640,25941,818,421,3,3,sc3,none,line 4,0,sub-line,line 4 part 5,811,401,13,30,,=,=,1,48102.60863,1.01E-05
# 8960 l6_sc3,line 4 part 6,5,sc,3,837,418,125,8853,8978,837,418,3,5,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8961 l6_sc3,line 4 part 6,5,sc,3,833,420,208,9354,9562,833,420,3,5,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8962 l6_sc3,line 4 part 6,4,sc,3,832,413,192,12932,13124,832,443,3,4,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8963 l6_sc3,line 4 part 6,5,sc,3,833,428,233,6517,6750,833,428,3,5,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8964 l6_sc3,line 4 part 6,5,sc,3,835,412,325,56762,57087,835,412,3,5,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8965 l6_sc3,line 4 part 6,3,sc,3,833,404,133,11490,11623,833,424,3,3,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8966 l6_sc3,line 4 part 6,5,sc,3,837,429,225,40776,41001,837,429,3,5,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8967 l6_sc3,line 4 part 6,3,sc,3,836,425,250,65181,65431,836,445,3,3,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8968 l6_sc3,line 4 part 6,3,sc,3,838,415,225,45999,46224,838,435,3,3,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8969 l6_sc3,line 4 part 6,3,sc,3,835,415,242,71705,71947,835,435,3,3,sc3,none,line 4,0,sub-line,line 4 part 6,831,401,8,30,,1,1,1,1065.386868,1.01E-06
# 8970 l6_sc3,line 4 part 7,3,sc,3,853,415,293,15978,16271,853,435,3,3,sc3,none,line 4,0,sub-line,line 4 part 7,848,401,5,30,,;,;,1,135664.4453,0.002448036
# 8971 l6_sc3,line 4 part 7,3,sc,3,850,421,100,19458,19558,850,441,3,3,sc3,none,line 4,0,sub-line,line 4 part 7,848,401,5,30,,;,;,1,135664.4453,0.002448036
# 8972 l6_sc3,line 4 part 8,3,sc,3,878,421,151,62502,62653,878,441,3,3,sc3,none,line 4,0,sub-line,line 4 part 8,859,401,28,30,,col,col,3,17.94496052,1.00E-06
# 8973 l6_sc3,line 4 part 8,3,sc,3,868,430,226,66849,67075,868,450,3,3,sc3,none,line 4,0,sub-line,line 4 part 8,859,401,28,30,,col,col,3,17.94496052,1.00E-06
# 8974 l6_sc3,line 4 part 8,3,sc,3,886,411,233,16279,16512,886,431,3,3,sc3,none,line 4,0,sub-line,line 4 part 8,859,401,28,30,,col,col,3,17.94496052,1.00E-06
# 8975 l6_sc3,line 4 part 8,3,sc,3,879,411,159,65439,65598,879,431,3,3,sc3,none,line 4,0,sub-line,line 4 part 8,859,401,28,30,,col,col,3,17.94496052,1.00E-06
# 8976 l6_sc3,line 4 part 8,3,sc,3,860,418,259,1477,1736,860,438,3,3,sc3,none,line 4,0,sub-line,line 4 part 8,859,401,28,30,,col,col,3,17.94496052,1.00E-06
# 8977 l6_sc3,line 4 part 8,3,sc,3,877,407,200,51097,51297,877,427,3,3,sc3,none,line 4,0,sub-line,line 4 part 8,859,401,28,30,,col,col,3,17.94496052,1.00E-06
# 8978 l6_sc3,line 4 part 8,4,sc,3,870,430,292,18305,18597,870,460,3,4,sc3,none,line 4,0,sub-line,line 4 part 8,859,401,28,30,,col,col,3,17.94496052,1.00E-06
# 8979 l6_sc3,line 4 part 9,4,sc,3,909,419,251,10654,10905,909,449,3,4,sc3,none,line 4,0,sub-line,line 4 part 9,893,401,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8980 l6_sc3,line 4 part 9,4,sc,3,895,417,192,18105,18297,895,447,3,4,sc3,none,line 4,0,sub-line,line 4 part 9,893,401,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8981 l6_sc3,line 4 part 9,5,sc,3,895,402,184,39315,39499,895,402,3,5,sc3,none,line 4,0,sub-line,line 4 part 9,893,401,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8982 l6_sc3,line 4 part 9,4,sc,3,894,407,184,20124,20308,894,437,3,4,sc3,none,line 4,0,sub-line,line 4 part 9,893,401,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8983 l6_sc3,line 4 part 9,3,sc,3,904,415,184,67917,68101,904,435,3,3,sc3,none,line 4,0,sub-line,line 4 part 9,893,401,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8984 l6_sc3,line 4 part 9,3,sc,3,906,409,267,20317,20584,906,429,3,3,sc3,none,line 4,0,sub-line,line 4 part 9,893,401,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8985 l6_sc3,line 4 part 9,3,sc,3,917,407,301,17872,18173,917,427,3,3,sc3,none,line 4,0,sub-line,line 4 part 9,893,401,25,30,,<=,<=,2,448.9502851,1.01E-06
# 8986 l6_sc3,line 5 part 2,3,sc,3,920,448,133,83645,83778,920,468,3,3,sc3,none,line 5,0,sub-line,line 5 part 2,920,438,8,30,,(,(,1,1602.756868,0.001516968
# 8987 l6_sc3,line 5 part 3,4,sc,3,944,452,225,43853,44078,944,482,3,4,sc3,none,line 5,0,sub-line,line 5 part 3,932,438,18,30,,*',*',2,0,1.01E-06
# 8988 l6_sc3,line 5 part 3,4,sc,3,943,460,384,23745,24129,943,490,3,4,sc3,none,line 5,0,sub-line,line 5 part 3,932,438,18,30,,*',*',2,0,1.01E-06
# 8989 l6_sc3,line 6 part 1,4,sc,3,712,500,117,208,325,712,530,3,4,sc3,none,line 6,0,sub-line,line 6 part 1,705,475,9,30,,},},1,43801.58225,0.0935448
# 8990 l6_sc3,line 7 part 2,5,sc,3,882,527,159,20075,20234,882,562,3,5,sc3,none,line 7,0,sub-line,line 7 part 2,882,512,8,30,,(,(,1,1602.756868,2.54E-05
# 8991 l6_sc3,line 7 part 2,5,sc,3,883,521,150,12516,12666,883,556,3,5,sc3,none,line 7,0,sub-line,line 7 part 2,882,512,8,30,,(,(,1,1602.756868,2.54E-05

# %%
#testing participants dictionary idea
participants['l1_sc1']
# Out:
# ['13', '11', '4', '8', '1', '10', '12', '6', '7', '5', '2', '9']

# %%
#testing word dictionary idea
lexicon["l1_sc1" + "line 1 part 2" +"6"].get_basic_info()
# Out:
# "l1_sc1  1  2  class  ['6', '6']  [100, 100]  [1705, 25]  5  2563  0.01059009"

# %%
#output everything into a file called NT-EZ-style-output.csv
#output style: SFD 231 FFD 227 GD 269 TT 290 PrF 0.95 Pr1 0.90 Pr2 0.05 PrS 0.05 class

out = open('Novice-EZ-style-output-persubject.csv', 'wt')
#writing the header
out.write("SFD,FFD,GD,TT,PrF,Pr1,Pr2,PrS,word,freq,pred,leng,subj,level" + "\n")

count = 0
for word in lexicon:
    count += 1
    #print(count, line)
#     print(lexicon[word].get_basic_info())
#     print("SFD:", str(lexicon[word].single_fix_duration()))
#     print("FFD:", str(lexicon[word].first_fix_duration()))
#     print("GD:", str(lexicon[word].gaze_duration()))
#     print("TT:", str(lexicon[word].total_time()))
#     print("PrF:", str(lexicon[word].fix_probability()))
#     print("Pr1", str(lexicon[word].prob_of_one_fix()))
#     print("Pr2:",  str(lexicon[word].prob_of_2_or_more_fix()))
#     print("PrS:",  str(lexicon[word].prob_of_skip()))
#    print(lexicon[word].get_text())    
    
#     out.write("SFD " + str(lexicon[word].single_fix_duration()) +\
#               " FFD " +  str(lexicon[word].first_fix_duration()) +\
#               " GD " +  str(lexicon[word].gaze_duration()) +\
#               " TT " +  str(lexicon[word].total_time()) +\
#               " PrF " +  str(lexicon[word].fix_probability()) +\
#               " Pr1 " +  str(lexicon[word].prob_of_one_fix()) +\
#               " Pr2 " +  str(lexicon[word].prob_of_2_or_more_fix()) +\
#               " PrS " +  str(lexicon[word].prob_of_skip()) +\
#               " " + lexicon[word].get_text() +\
#               " freq " + str(lexicon[word].get_freq()) +\
#               " pred " + str(lexicon[word].get_pred()) +\
#               " leng " + str(lexicon[word].get_leng()) + "\n"   )
    
    #write data
    out.write(str(lexicon[word].single_fix_duration()) +\
              "," +  str(lexicon[word].first_fix_duration()) +\
              "," +  str(lexicon[word].gaze_duration()) +\
              "," +  str(lexicon[word].total_time()) +\
              "," +  str(lexicon[word].fix_probability()) +\
              "," +  str(lexicon[word].prob_of_one_fix()) +\
              "," +  str(lexicon[word].prob_of_2_or_more_fix()) +\
              "," +  str(lexicon[word].prob_of_skip()) +\
              "," + lexicon[word].get_text() +\
              "," + str(lexicon[word].get_freq()) +\
              "," + str(lexicon[word].get_pred()) +\
              "," + str(lexicon[word].get_leng()) +\
              "," + str(lexicon[word].get_subject())+\
              "," + str(lexicon[word].get_level())[:2] +"\n"      )

out.close()

# %%
len(lexicon)
# Out:
# 2584

# %% [markdown]
# round, session, participant, code_file, code_language, timestamp, duration, x_cord, y_cord, aoi_x, aoi_y, aoi_width, aoi_height, token, length
